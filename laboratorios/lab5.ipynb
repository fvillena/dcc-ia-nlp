# %% [markdown]
# # Laboratorio 5: clasificación de texto usando RNN.
#
# ##### <strong>Manejo archivos y Pandas </strong>
#
# ### Cuerpo Docente
#
# - Profesores: [Andrés Abeliuk](https://aabeliuk.github.io/), [Felipe Villena](https://fabianvillena.cl/).
# - Profesor Auxiliar: [Gabriel Iturra](https://giturra.cl/)

# %% [markdown]
# ## **Preguntas 💻** ##

# %% [markdown]
# El Deep Learning es la técnica que logra el estado del arte en múltiples tareas de modelamiento de tareas que utilicen datos no estructurados. En procesamiento de lenguaje natural tiene sentido utilizar un tipo de redes neuronales llamadas recurrentes debido a que toman en cuenta el orden de los elementos en una secuencia para representar los datos de entrada.
#
# A usted se le entrega un conjunto de datos de síntomas asociados a una enfermedad y se le pide entrenar un modelo de clasificación para sugerir la enfermedad relacionada a la descripción sintomática del paciente.
#
#
# Por lo que usaremos el dataset de diagnosticos en español, que hemos estado trabajando en clase.

# %% [markdown]
# Para realizar la clasificación del dataset usando el contenido en el archivo, se le pida crear una arquitectura basada en redes neuronales recurrentes utilizando `PyTorch`. Dado que necesitamos programar una arquitectura en redes neuronales necesitamos es necesario trabajar en Google Colab, ya que necesitaremos acceso a GPUs. Por el primer paso es cargar este archivo a Google Colab, luego realizar los siguientes pasos:

# %% [markdown]
# ### Cargar el dataset

# %% [markdown]
# Para descargar el dataset debemos instalar la librería `datasets`, que contiene muchos datasets subido a `huggingface`, que ya hemos utilizados. Por lo que ejecutamos el comando:

# %%
# !pip install datasets
# Out:
# Collecting datasets
#   Downloading datasets-2.14.6-py3-none-any.whl (493 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 493.7/493.7 kB 8.8 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (1.23.5)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (9.0.0)
# Collecting dill<0.3.8,>=0.3.0 (from datasets)
#   Downloading dill-0.3.7-py3-none-any.whl (115 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 19.3 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (1.5.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (4.66.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets) (3.4.1)
# Collecting multiprocess (from datasets)
#   Downloading multiprocess-0.70.15-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 20.3 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]<=2023.10.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.8.6)
# Collecting huggingface-hub<1.0.0,>=0.14.0 (from datasets)
#   Downloading huggingface_hub-0.19.0-py3-none-any.whl (311 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 311.2/311.2 kB 40.2 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (6.0.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (3.3.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0.0,>=0.14.0->datasets) (3.13.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0.0,>=0.14.0->datasets) (4.5.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (2023.7.22)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2023.3.post1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->datasets) (1.16.0)
# Installing collected packages: dill, multiprocess, huggingface-hub, datasets
# Successfully installed datasets-2.14.6 dill-0.3.7 huggingface-hub-0.19.0 multiprocess-0.70.15

# %%
import datasets
spanish_diagnostics = datasets.load_dataset('fvillena/spanish_diagnostics') # Con esta linea descargamos el conjunto de datos completo
# Out:
# Downloading builder script:   0%|          | 0.00/1.67k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/6.85M [00:00<?, ?B/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating test split: 0 examples [00:00, ? examples/s]

# %%
spanish_diagnostics['train']['text']
# Out:
# ['- ANOMALÍAS DENTOFACIALES (INCLUSO LA MALOCLUSIÓN)\n\n\n DISCREPANCIA DENTOMAXILAR',
#  'OBTRUCCION FOSA NASAL DERECHA',
#  'Perturbación de la actividad y de la atención Trastorno defícit atencional',
#  'M7 PROLAPSO VAGINAL PARED ANTERIOR G11 G 111 ALGIA PELVICA HTA CRONICA',
#  'PIEZA 3 CARIES DENTINARIA PROFUNDA PROXIMA A CAMARA PULPAR, EVALUAR POR ESPECIALIDAD',
#  'pieza n 3.4 tratada endodonticamente, restaurada con ionomero y resina compuesta. Necesita protesis fija por gran pNrdida coronaria',
#  'PZ. 12 TREPANADA',
#  'CARCINOMA TORIODEO',
#  'DISPEPSIA Y METEORISMO',
#  'ASA 1 DENTICION TEMPORAL MORDIDA CRUZADA',
#  '- DISMINUCION DE AGUDEZA VISUAL. - ESCATOMAS O.D.',
#  'K028 OTRAS CARIES DENTALES ABFRACCIONES EN DIENTES 9, 10, 11',
#  'DIENTE 1,5 TREPANADO',
#  'PZA 4.6 PULPITIS IRREVERSIBLE, DOLOR A CAMBIOS TECNICOS DE LARGA DURACION, CARIES OD PROXIMA A CAMARA PULPAR.',
#  'enfermedad periodontal generalizada. movilidad',
#  'INSERCIÓN B AJA DEL FRENILLO LABIAL',
#  'PRESENCIA DE DISPOSITIVO ANTICONCEPTIVO INTRAUTERINO',
#  '-PIEZA 1.3 SEMIINCLUIDA',
#  '- TRASTORNO DE LA REFRACCIÓN, NO ESPECIFICADO/  - Fundamento Clínico APS: paciente hace varios años menor agudeza visual, usuaria de lentes cuando fue pequeñarelata mayor dificultad en vision a corta y larga distancia',
#  '- ANOMALÍAS DENTOFACIALES (INCLUSO LA MALOCLUSIÓN)/  - Fundamento Clínico APS: Paciente sano Odontológico, se deriva para evaluación y tratamiento  por malolcusión dentraia, presenta incisivos laterales superiores e inferiores en giroversión. Con probalid',
#  'HERNIA ABDOMINALSUPRAUMBILICAL',
#  'QUELOIDES LOBULO OIDO DERECHO',
#  'ADENOMIOSIS UTERINA ACENTUADA',
#  'pancreatitis aguda de origen desconocido obs microlitiasis vesicular ob tu ampular usuario marcapasos',
#  'APIÑAMIENTO DENTARIO, MORDIDA INVERTIDA ANTERIOR Y CRUZADA POSTERIOR UNILATERAL DERCHO. MORDIDA POSTERIOR IZQUIERDO BIS A BIS',
#  '- ANOMALÍAS DENTOFACIALES (INCLUSO LA MALOCLUSIÓN)\n\n\n Paciente presenta mordida invertida . Ausencia de caries.',
#  'EXAMEN ODONTOLOGICO: PACIENTE CON COMPRESION DE MAXILARES, APIÑAMIENTO DENTARIO, MORDIDA INVERTIDA INFERIOR.',
#  'DISMINUCION DE AGUDEZA VISUAL OBSERVACION CONJUNTIVITIS ALERGICA',
#  '- MULTIPLES LESIONES CARIOSAS',
#  'DESDENTADA PARCIAL INEFRIOR',
#  'Pieza 2.8 semierupcionada',
#  'espasmo vascular , neurologia trigeminal.',
#  'PERIODONTITIS CRONICA SEVERA LOCALIZADA GRUPO II',
#  'PIEZA 3 NECROSIS PULPAR, TERAPIA PREVIAMENTE INICIADA.',
#  'maloclusion de tipo no especifico',
#  'EXFOLIACIÓN DE TERCEROS MOLARES PIEZA 17, 32,1',
#  'PIEZA 8 FRACTURA CORONARIA, POSIBILIDAD DE REHABILTAR MEDIANTE PROTESIS FIJA',
#  'paciente hta asa 2 pd 20 pulpitis cronica irreversible  trepanada',
#  'PULPITIS DOLOROSA',
#  'DESDENTADO TOTAL MAXILAR Y PARCIAL MAND.',
#  'C. A DE MAMA USO DIFOSFONATO',
#  'M1 CCA X Macrosomía Embarazo 11 semanas litisis renal',
#  '- NEURALGIA Y NEURITIS, NO ESPECIFICADAS/  - Fundamento Clínico APS: PACIENTE VISTA EN URGENCIA CON DX DE NEURALGIA INTERCOSTAL IZQUIERDA DE 1 AÑO DE EVOLUCION QUE NO CEDE AL TRATAMIENTO FARMACOLOGICO Neuralgia y neuritis, no especificadas',
#  'LUMBAGO CRONICO EMBARAZO 11 SEMANAS',
#  'MOLOCLUCION DENTINCION PERMANENTE',
#  'DIENTE 2.6 CON PULPITIS IRREVERSIBLE',
#  'CARIES DENTARIA PROFUNDA PZ N° 2.6',
#  '1.- PZA 11 PULPITIS CRONICA TREPANACION DE URGENCIA',
#  'OBS. MIELANOMA MULTIPLE',
#  'PERIODONTITIS CRONICO LOCALIZADA',
#  'TRASTRONO DE LA PROSTATA',
#  'HIPERTROFIA ADENOIDEA .',
#  'CEFALEA REFRACTARIA AGUDA',
#  'Feto Y R.n. Afectados Por Polihidramnios',
#  'PACIENTE DENDENTADA TOTAL MAXILAR Y MANDIBULAR REBORDE ALVEOLAR DESFABORABLE',
#  'ANOMALIA DE AXENFELD RIEGER',
#  'PERIODONTITIS CRONICA LOCALIZADA 3.7',
#  'verruga en parpado',
#  '-apiñamiento dentario',
#  'ACCIDENTE CEREBRO VASCULAR ISQUIMICO',
#  'Bocio Sintomatico',
#  'OBS GRANULOMA TALON',
#  'PZA 8 /9   22/ 27',
#  'OBS ORQUIEDIDIMITIS BILATERAL CRONICA IZQ',
#  '4.2 -4.1 lesion endoperiodontal dolor periodico aumento de volumen',
#  'pd. 4,7 pulpitis irreversible',
#  'DESARMONIA DENTOMAXILAR FALTA ESPACIO PIEZAS ANTERIO INFERIOR Y PIEZA 12 EN VENTO OCLUSION.',
#  'diente 4.8 erupcionado co nparde osea distal y ra??z mesdial curvada hacia distal y dital hacia mesial.',
#  'DIASTEMIA ANTEROSUPERIOR LEVE',
#  'LUXACION, ESGUINCE Y DESGARRO DE ARTICULACION RODILLA',
#  'P. 1.1 DOLOR AGUDO',
#  'M2 DOBLE CESAREA ANTERIOR POR DLP EMBARAZO DE 11 SEMANAS +2 DIAS. HTA CRONICA.',
#  'devolver overbite adecuado mordida abierta anterior por lengua desendida',
#  'P 6 CARIES',
#  'PERIODONTITIS CRONICA SEVERA GENERALIZADA, ESTOMATITIS SUBPROTESICA',
#  'Apoplejia Hipofisiaria',
#  'DTE 6 INCLUIDO EVALUAR TTO.',
#  'EXAMEN ODONTOLOGICO, PERIODONTITIS APICAL AGUDA.',
#  'Paciente Portador De Enfermedad Renal Poliquistica Y Cardiopatia Coronariarevascularizada El A?o 2002ingresa Dialisis Peritoneal En Clinica Davila',
#  'Contucion  Mano Izquierda',
#  'blefaroespasmo ocasional',
#  'dg. argia lingual en estudio',
#  'Q35.9 FISURA DEL PALADAR UNILATERAL, SIN OTRA ESPECIFICACION',
#  'PACIENTE CON DENTINCION CLASE I MOLAR. APIÑAMIENTO DENTARIO MANDIBULAR.',
#  'M2, HTA, Hipotiroidismo, dislipidemia, con antecedentes de ca de mama familair, Usuaria de DIU. Mx 4',
#  'PIEZA 4 EN PROCESO DE TRACCION ORTODONCIA',
#  '- ANOMALÍAS DE LA POSICIÓN DEL DIENTE\n\n\n Paciente clase I esqueletal con leve desviación mandibular derecha. Mordida invertida anterior y diente 2.3 vestibularizado. Contacto en oclusión de 1.1 y 4.1.',
#  'TRANSTORNO DESARROLLO DE PERSONALIDAD',
#  'mailgia masticatoria plano',
#  'PIEZA 7.5 Y 8.5 CON CARIES PROFUNDAS, GRAN DESTRUCCION CORONARIA SE DERIVA PARA EVALUAR POSIBILIDAD DE TRATAMIENTO PULPAR PARA MANTENCION DE ESPACIO',
#  'PASE OPERATORIO COXASTROSIS SEVERA',
#  'MULTIPLES GIROVERSIONES EN SECTOR ANTERO SUPERIOR DENTICIÓN MIXTA PRIMERA FASE LIBRE DE CARIES NECESIDAD DE TTO ORTOPEDICO',
#  'Paciente con antecedentes de TDA 8, 9, 25, piezas tratadas pero con restauraciones desajustadas y antiestéticas. Solicito evaluar POSIBILIDAD DE REHABUILITACIÓN P. 8,9 Y 25.',
#  'DEFICIT ATENCINAL',
#  'DESCARTAR  GMN  V/S NEFRITIS INTERTICIAL  LITIASIS RENAL  MICROHEMATURIA',
#  'evaluación por especialidad\nPaciente TACO',
#  'OBS DE PSORIASIS.',
#  'anomalias dentofaciales (incluso malocclusion)',
#  'QUISTE SINODIAL MANO IZQ.',
#  'dte pza 9',
#  'PIEZA 1,8 CARIES',
#  'pieza 14 caries dentinaria penetrante, trepanada',
#  'HIPERTROFIA AMIGDALAR AMIGDALITIS SEPTICA',
#  'OBS. SINDARTILIA PULGAR DERECHO',
#  'EXAMEN ODONTOLOGICO posibilidad de tto para pieza 2.1',
#  'CONJUNTIVITIS REPETITIVA',
#  'abceso parcial sintomatico',
#  'pieza 4 espera endodoncia, destruccion coronaria marcada.',
#  'artrosis de cadera derecha, espolon calcaneo bilateral',
#  'Ca De Endometrio -dolor Toraxico Atipico',
#  'SECION SIMPLE/BIOPSIA BUCO-FARINGEA',
#  'PERIODONTITIS APICAL AGUDA PIEZA 1,5',
#  'LESION CONDUCTO AUDITIVO EXTERNO DERECHO A ESTUDIO',
#  '- OTRAS ENFERMEDADES PERIODONTALES/  - Fundamento Clínico APS: perdida de soporte, reatraccion gingival, bruxismo Otras enfermedades periodontales',
#  'fractura nasoseptal',
#  'TDAH ? OBS. TEA',
#  'UNICOMICOSIS.',
#  'PZA 19 CARIES DENTARIO PROFUNDO',
#  'paciente porta pfp desde pza 7 a 10 en mal estado',
#  'Alergico rash',
#  'PIEZA TRATADA ENDODONTIC.',
#  'PIEZAS 7.4 Y 8.4 CON CARIES DENTINARIA PROFUNDA PROXIMA A CAMARA PULPAR, EVALUAR POSIBILIDAD DE REALIZAR PULPOTENCIAS.',
#  'PD 4.4 PULPITIS IRREVERSIBLE (DIAGNOSTICO APICAL: PERIODONTITIS APICAL CRONICA)',
#  'HIPOACUSIA SECUNDARIA',
#  'EPISTAXIA 2ª A USO DE AAS. CARDIOPATIA EN TTO.',
#  'adenopatia en studio',
#  'hernia inguinal derecha,sin otros antecedentes morbidos conocidos,imc 21.3',
#  'PIEZA 3.8 CARIES  DENTINARIA  PROFUNDA',
#  '1.- APIÑAMIENTO INFERIOR 2.- MAL OCLUSION',
#  'calse II subdivision',
#  'PZA: 4 Y5 NECROSOS PULPAR, PZA: 4 PERIODONTITIS APICAL CRONICA',
#  'PIEZA TREPANADA 2 Y 6',
#  'DIENTE 17 INCLUIDO IMPACTADO, 32 INCLUIDO IMPACTADO',
#  'DG. 11632SEMINCLUIDAS.SOLICITA EXODONCIA POR INDICACION DE ORTODONCIA.ADJUNTA RX.',
#  'Icc Evaluacion Cardiologica',
#  'pza 12 cavidad inmediata con area pulpor',
#  'BRADICARDIA EXTREMA BLOQUEO AV HERNIAS',
#  'Sdm Dawn',
#  'tu renal op 2008 en concepcion sin control',
#  '1) ENFERMEDAD RENAL CRONICA 2) USUARIO HEMODILIASIS',
#  'PCTE CON PERIODONTITIS GENERALIZADA SEVERA GRUPÒ 2 X 5',
#  'SUPERNUMERARIA. ADYACENTE P 2.1 SEMIERUPCIONADA',
#  '- CARIES DENTAL/  - Fundamento Clínico APS: pacte con caries profunda 4.6, caries no se eliminanase indicva tto de endodoncia   Caries dental',
#  'Dolor Abdominal Inespecifico Recurrente',
#  'pd 3.7 trepanada con rx',
#  'Evaluaciobn Previa A Cirujia Otorganica',
#  'Deterioro Visual Sin Especificar (binocular)',
#  'pieza 3.2 y 4.2 retenidas en giroversion',
#  '- ANOMALÍAS DENTOFACIALES (INCLUSO LA MALOCLUSIÓN)\n\n\n Paciente de 6 años, sana, dent mixta 1ra fase presenta mordida abierta anterior asociado a mal hábito (succión digital).\nOverbite - 5 mm\nSolicito realizar evaluacion y tratamiento pertinente',
#  '- ANOMALÍAS DENTOFACIALES (INCLUSO LA MALOCLUSIÓN)/  - Fundamento Clínico APS: pacte con anomalia dento maxilar, clase 2 de angle sobre mordida horizontal y vertical aumentado  Anomalias dentofaciales (incluso la maloclusion)',
#  'RESECION GINGIVAL',
#  '(O48) EMBARAZO PROLONGADO',
#  '-TRASTORNO CONDUCTUAL + OBS DE SONAMBULISMO.',
#  'DIENTE SEMI - INCLUIDO',
#  'ENFERMEDAD DE DUPUYTREN MANO DER',
#  'PZA 1.3 Y 2.3 VESTIBULARIZADAS MORDIDA RUZADA POST IZQ.',
#  'SE SOLICITA PROTESIS INMEDIATA PIEZA 9',
#  'Ppsi',
#  'J030.1 - Amigdalitis estreptococica / Amigdalitis estreptococica',
#  'HIPERPLASIA PAPILAR Y GINOVAL',
#  'POSIBILIDAD DE EXXODONCIA 1,16,17,32, INDICACION DE ORTODONCIA',
#  'Paciente Compromiso Presidencial A?o 2012 Sin Apnea Obstructiva Sin Control Por 2 A?os',
#  'APINAMIENTO PIEZA 6 - 11 EVOLUCION VESTIBULAR ALTA,FALTA ESPACIO PIEZA 22-27 FALTA ESPACIO PARA EVOLUCION',
#  'EDENTADA PARCIAL, HTA, TABAQUISMO CRONICO, RM, EPI',
#  'ADM EN SENTIDO VERTICAL',
#  'ABSCESO PERIANAL D',
#  'Paciente sexo masculino, 14 años 5 meses. Dentición definitiva, Presenta sobremordida y apiñamiento grupo V, con p. 3.1-4.1 levemente extruídas. Se solicita tratamiento por especialista',
#  'RNT 38 SEMANAS PEG SEVERO BRADICARDIA EN ESTUDIO',
#  'FALTA DE ESPACIO  APIÑAMIENTO DENTARIO',
#  'DENTICION MIXTA 2DA FASE FASE OVERJET Y OBITA AUMENTADO VESTIBLOVERSIA ENTERO SUPERIOR',
#  '- OBESIDAD GRADO II/  - Fundamento Clínico APS: AM: NO  QX: NO  ALERGIA A FCO: NO   PACIENTE EN CONTROL NUTRICIONAL HACE MAS DE 1 AÑO POR OBESIDAD, SIN RESPUESTA FAVORABLE. MADRE REFIERE QUE SIGUE DIETA PERO MENOR SACA COMIDA A ESCONDIDAS.  PESO:  33.7 TALLA: 119  PRESION ARTERIAL NORMAL LIMITE MAX  EX HEMOGRAMA NORMAL  GLICEMIA 88  TG: 166 COL T 174  TSH: 4.53   EX FISICO SIN ALTERACIONES.  ANT FAMILIARES DE OBESIDAD MORBIDA.  Obesidad grado II',
#  '- CEFALEA/  - Fundamento Clínico APS: paciente que presenta hace 1 mes aproximadamente , dolor de cabeza de localizacion  parietal izquierda , que le aparece en cualquier momento del dia hasta cuando esta acostada . este dolor se le acompaña de mareos ocasionales y de vision borrosa . sin otro sintoma  referido . derivo a especialista para evaluacion del caso .  Cefalea',
#  'PACIENTE RELATA DOLOR ARTICULAR, HACE 3 MESES, MAYOR INTENSIDAD AL LADO IZQUIERDO, DOLOR A LA PALPACION ATM IZQUIERDA POLO EXTERNO, CONSULTO A OTORRINO QUE DESCARTA ORIGEN OTICO. SE DERIVA PARA EVALUACION ONICOTAGIA.',
#  '- ANOMALÍAS DENTOFACIALES (INCLUSO LA MALOCLUSIÓN)/  - Fundamento Clínico APS: Hombre 12 años, tendencia a clase II molar bilateral, discrepancia dentomaxilar y mandibular  negativa con apiñamiento.  Anomalias dentofaciales (incluso la maloclusion)',
#  'Pcte 8 anos de edad con piezas 1.3 y 2.3 incluidas y sin espacio para erupcionar. se solicita evaluacion y posibilidad de tratamiento. gracias',
#  'TUMOR DE COMPORTAMIENTO INCIERTO O DESCONOCIDO DEL UTERO / TUMOR DE COMPORTAMIENTO INCIERTO O DESCONOCIDO DEL UTERO',
#  'PIEZA 14 PERIODONTITIS APICAL SINTOMATICA.',
#  'CARIES PROFUNDA P17',
#  'OBS. BASE FALANGE MEDIA SEGUNDO DEDO IZQ ANTIGUA HTA, DLP',
#  'FRENILLOLECTOMIA',
#  'Paciente Con Sindrome De Down,Evaluacion.',
#  'LESION APICAL PIEZA 19',
#  'PULPITIS IRREVESTILE SINTOMATICA',
#  'DIAGNOSTICO DE DIVERTICULITIS',
#  'PACIENTE PRESENTA PULPITIS CRONICA PIEZA 12, SE REALIZA TREPANACION DE URGENCIA Y SE DEJA CON CURACION CON FORMOCRESOL.',
#  '- TRASTORNOS DE LA CONDUCTA/  - Fundamento Clínico APS: paciente en psicoterapia por trastorno de conducta con episodios de aparentes reacciones catastrovicas (vs pataletas) asociados  aepisodio de ira y descontrol de impulsos, ademas de frustracion por ejemplo cuando le tienen que pedir que se levante para ir a la escuela o cuando le dicen que termino su tiempo de uso del telefono celular. esto ultimo viene ocurriento hace mas de 2 años, asociado a baja de notas importante este ultimo año, si paciente mantiene notas repetira a final de año. madre refiere que en general no toma apuntes en escuela y que se aburre. no refiere sintomas asociados de hiperactividad. paciente presenta episodios de irritabilidad frecuentes, con reacciones de agresividad durante "pataletas, con golpes a los muebles y objetos y amenazas de que se tirará de un puente o que prefiere "morir si no tiene el celular", aparentemente no esta midiendo adecuadamente riesgos. hermano pequeño con miedo constante asociado a estas reacciones.  a la entrevista paciente poco comunicativo, le cuesta expresar sus emociones cuando se le pregunta acerca de estas durante sus episodios de reacciones agresivas, se le consulta que piensa acerca de estas situaciones, no respondiendo si le parece bien o mal, pero si lenguaje no verbal expresa verguenza. aparentemente heteroculpable, refiere que le cae mal su familia porque lo molestan mucho y siempre le repiten las mismas cosas y que lo presionan siempre. paciente niega anhedonia y labilidad emocional con juicio de realidad conservado, sin sintomas psicoticos ni alucinaciones.  se realizan examenes de laboratorio y se descarta anemia e hipotiroidismo.  con mala respuesta a psicoterapia de los ultimos 7 meses, sin lograr mejoria significativa en paciente, por lo que se decide derivar. Trastornos de la conducta',
#  'R51X CEFALEA RONCOPATIA',
#  'ADAC DIENTE 9',
#  '- CÁNCER DEL CUELLO UTERINO/  - Fundamento Clínico APS: PACIENTE CON ANTEC DE HUN BILÑATERAL MODERADA EN ULTIMO TAC 2RIA A FIBROSIS ACTINICA DE PELVIS?. SE REALIZO IC EN AGOSTO DE 2008 EN ANTOAGASTA. ACUDEN HOY 7 MESES MAS TARDE PARA SOLICITAR IC A SS ATA',
#  '- ALTERACIONES EN LA ERUPCIÓN DENTARIA/  - Fundamento Clínico APS: Paciente con apiñamiento anterior superior e inferior, con diente 4.5 lingualizado. Alteraciones en la erupcion dentaria',
#  'URGEINCONTINENCIA  ENURESIS',
#  'P7 Y 8 TREPANADAS',
#  '- DEPRESION MODERADA - IDEACION SUICIDA',
#  'GONARTROSIS  IZQ SEVERA',
#  'periodontal pieza 17 mas deabetes',
#  'A.R - FIBROMIALGIA',
#  'K075 ANOMALÍAS DENTOFACIALES FUNCIONALES clase III, hipoplasia maxialr',
#  'ENFERMEDADES DE MULTIPLES VALVULAS',
#  '- Pcte. de 11 años con dentición mixta, completando segunda fase de recambio - Molar clase III - Mordida abierta - Apinamiento de caninos',
#  'caries penetrante diente 3, LPA ensanchada',
#  'GASTROPATA ATROFICA ANATAL',
#  'ALTERACIONES EN LA CORNEA',
#  '.- VICIO DE REFRCCION.',
#  'usuario desdentado parcial maxilar y mandibular, usa protesis maxilar en mal estado. Se solicita tto por especialidad. OBS: pzas 3.2, 3.4 y 2.5 evaluar por movilidad leve.',
#  'TRASTORNO DEL CONDUCTO DEFERENTE',
#  'PZA. 1,5 FRACTURA CORONARIA. CONDUCTO TRATADO ( EN TTO.)',
#  'COMPRESION MAXILAR MORDIDA INVERTIDA LADO DERECHO MAS P.7 Y 10 EN POSICION PALATINA. P. 6 Y 11 EN POSICION ALTA VESTIBULAR SIN ESPACIO PARA DESCENDER.',
#  'Diente 18 con mal pronostico rehabilitador   implante',
#  'DEDENTADO TOTAL SUPERIOR Y PARCIAL INFERIOR',
#  'DESDENTADO PARCIAL BI MAXILAR',
#  'DESDENTADA TOTAL MAX. Y MAND. PARCIAL.',
#  'necrosis palpar diente 2.5 multirradicular',
#  'nevo cong',
#  'PACIENTE DESDENTADA PARCIAL,AUSENCIA DE PIEZA 2.4',
#  'Dolor abdominal persistente diarrea crónica.',
#  'evaluacion por oftalmo s sicca',
#  'Obs. Meniscopatia derecha',
#  '1. NAC atipico en resolución. 2. Insuficiencia respiratoria aguda resuelta.',
#  'diente 8 incluido',
#  'BRUXISMO EXTENSIVO, SALTO ARTICULAR ATM DERECHA, DESVIACION MANDIBULAR HACIA LA IZQUIERDA.',
#  'hemofilia a grave memorragia digestiva',
#  'PZA 1.1 CON TRATAMIENTO DE CONDUCTO INCONCLUSO POR ABANDONO DE UN AÑO APROX. ATRAS ACUDE HOY CON FRACTURA DE CORONA ATRAS. ACUDE HOY CON FRACTURA DE CORONA.',
#  'D84.1 - DEFECTO DEL SISTEMA DEL COMPLEMENTO',
#  '(M243) LUXACION Y SUBLUXACION PATOLOGICA DE LA ARTICULACION, NO CLASIFICADAS EN OTRA PARTE',
#  '- TRASTORNOS DEL NERVIO AUDITIVOOtitis media , tinnitus. /  - Fundamento Clínico APS: Pcte masculino de 51 años de edad , sin antecedentes morbidos conocidos , el cual presenta desde chico otalgia , mucha otitis media supurativa e no supurativa , ademas con tinnitus y diminucion auditiva leve . Al examen otoscopico oidos eritematosos e inflamados .  se decide la interconsulta para evaluacion y tratamiento.  Trastornos del nervio auditivo',
#  'Pieza 22 retenida a  la altura de raices  de incisivos  infriores provocando rizalisis',
#  'OTRA PATOLOGIA EMBARAZO CON IMPLANTE',
#  'apertura bucal limitada diente 32 dificil acceso diente 16 con inclinacion a vestibular',
#  'pieza n 5 caries dentinaria profunda',
#  'DIABETES 2 enfermedad 3 vasoshta',
#  'M4 PROLAPSO PARED VAGINAL II° INCONTINENCIA URINARIA DE URGENCIA. QUISTES URETRALES TRATADOS.',
#  'M.  ROTADOR // PCTE RETIRA ORIGINAL 01/03/2011',
#  'pieza 4.8 - 3.8 erupcion parcial dolorosa',
#  'OBS: ASTIGMATISMO /MIOPIA',
#  'paciente denticion definita clase I de angle bilateral multiple giroversiones grupo V.',
#  'APIÑAMIENTO DENTARIO, FALTA DE ESPACIO,',
#  'EVALUAR PARA PROTESIS FIJA UNITARIA P. 8, FAVOR PRIORIZAR',
#  'SOS. OBSTRUCCION VIA LAGRIMAL',
#  'Cambios En Las Membranas De La Cornea',
#  'STC   BILATERAL',
#  'OBS VICIO DE REFRECCION',
#  'EVALUACION Y POSIBILIDAD DE ENDODONCIA PIEZAS 17 - 32 SEMIINCLUIDAS',
#  'K040 PULPITIS PULPITIS PRIMER PREMOLAR INFERIOR IZQUIERDO ( P. 28)',
#  'ar nash ?',
#  '- ANOMALÍAS DENTOFACIALES (INCLUSO LA MALOCLUSIÓN)/  - Fundamento Clínico APS: Solicita evaluación y factibilidad de realizar tratamiento. Clase II-paladar ojival. Anomalias dentofaciales (incluso la maloclusion)',
#  '- TRASTORNOS DE LA ARTICULACIÓN TEMPOROMAXILAR/  - Fundamento Clínico APS: PACIENTE PRESENTA CLICK EN APERTURA EN LADO IZQUIERDO, COMENTA MOLESTIAS AL MORDER Y MASCAR ALIMENTOS. Trastornos de la articulacion temporomaxilar',
#  'puerpera g2-p1-ao',
#  'DORSALGIA LUMBAGO (AC + FA)',
#  'VICIO DE REFRACCION, LAPOFTALMO OI',
#  'Q750 CRANEOSINOSTOSIS PEDIR HORA CON DR REQUENA',
#  'PZA. 13 CARIES PENETRANTE',
#  'PIEZA 4 CON PULPUTIS IRREVERSIBLE',
#  'DEMENCIA DE RAPIDA PROGRESION A CLASIFICAR',
#  'T810 - HEMORRAGIA Y HEMATOMA QUE COMPLICAN UN PROCEDIMIENTO, NO CLASIFICADAS EN OTRA PARTE / HEMORRAGIA Y HEMATOMA QUE COMPLICAN UN PROCEDIMIENTO, NO CLASIFICADAS EN OTRA PARTE',
#  'EPISTAXIS RECIENTEMENTE',
#  'OTRA PATOLOGIA TUMOR PALPABLE',
#  'Sospecha de Sindrome Mieloproliferativo',
#  'RNPRES HIPOTIRPOIDISMO',
#  '- P. 4.8 IMPACTADA.',
#  'S93.5',
#  'exodoncia pza supernumeraria intraosea,posicion vertical proyectada entre las raices de pzas 8-9',
#  '- PIEZA TREPANADA',
#  'paciente presenta enfermedad periodontal avanzada que afecta insisivos y mas de dos piezas distintas a estos perdida de grupo uno y movilidad generalizada antecedente familiar abuela pierde piezas dentarias muy temprana edad.',
#  'PREPUCION REDUNDANTE',
#  'paciente con indicacion de exodoncia pzas superiores y pza 18',
#  'P3 P14 CARIES PENETRANTES',
#  'Realización Ecocardiograma',
#  'Supernumerario diente 6-7.',
#  'M1 Usuaria DIU 23a',
#  '- Enfermedades De La Pulpa Y De Los Tejidos Pariapicales Pieza  3.4  Trepanada',
#  'Pulpitis irreversible 1.6',
#  'pza 1-17-32  semiincluidas',
#  'Bruxismo severo, en tratamiento por de depresion severa.',
#  'PIEZA 1.5 PULPITIS IRREVERSIBLE, TREPANACION, BIOPULPECTOMIA PMCFA Y FERMIN',
#  'PACIENTE PRESENTA ANOMALIA DENTOMAXILAR, CLASE I MOLAR DER.,CLASE II MOLAR IZQ., PALADAR OJIVAL, OVERJET AUMENTADO, MALPOSICION DIENTES 8 Y 9, APIÑAMIENTO DENTARIO GRUPO V',
#  'HEMORROIDES INTERNAS COMPLICADA',
#  'METASTASIS CEREBRALES (DESCARTAR TU PRIMARIO)',
#  'PACIENTE DESDENTADO SUPERIOR PARCIAL  Y TOTAL INF',
#  'AUGE 12 AÑOS',
#  'Quiste cabeza de epididimo bilateral',
#  'FX. MUÑECA',
#  'amenorrea EN ESTUDIO',
#  'MORDIDA CRUZADA E INVERTIDA IZQUIERDA',
#  'CARIES PIEZA 18 CON DESTRUCCION DE CORONA',
#  'EXAMEN ODONTOLOGICO CLASE 3, DESVIACION LINEA MEDIA ADM, OVERJET AUMENTADO',
#  'M3 (2 CCA) EMB 32+1 SEM',
#  'PZ. 1.6 - 2.5 EN MAL POSICION',
#  'terceros molares semi erupcionados pza 3.8 y 4.8',
#  'CLASE I DE ANGLE',
#  'TRASTORNO RITMO CARDIACO',
#  'TRANSTRONO DE LA CONDUCTA INSOCIABLE',
#  '- ANOMALÍAS DE LA POSICIÓN DEL DIENTE/  - Fundamento Clínico APS: PRESENTA DIASTEMA SUPERIOR Y PROTRUSION DE ZONA ANETRO SUPERIOS, CON SOBREMORDIDA, SE DERIVA PARA SU EVALUACION Y TRATAMIENTO Anomalias de la posicion del diente',
#  'PIEZA 5 TREPANDA',
#  'EVALUACION QUISTE PANCREATICO POR PANCREATITIS CRONICA',
#  'desdentado parcial superior diabetes tipo 2',
#  'MOLUSCO\xa0CONTAGIOSO / Desde\xa0hace\xa0un\xa0año\xa0presenta\xa0lesiones\xa0pruriginosas\xa0en\xa0cara\xa0y\xa0manos.',
#  'pieza 4.8 caries dentario profunda raíces dislaceradas convergente',
#  'DESDENTAMIENTO TOTAL BIMAXILAR.',
#  'Obs tu epididimo izquiedo Obs hernia inguinal larga data',
#  'PZA.5 PULPITIS',
#  'PIEZA 13 TREPANADA PULPITIS IRREVERSIBLE PIEZA 13',
#  'PIEZA 4   ABSCESO  APICAL   CRONICO',
#  'NEUMONIA PACIENTE DE RIESGO.',
#  'luxacion y subluxacion patologica de la articulacion',
#  'PZA 1.8-2.8 SEMIERUPCIONADAS  PZA 3.8 SEMI INCLUIDA',
#  '- TRASTORNOS DE LA ARTICULACIÓN TEMPOROMAXILAR/  - Fundamento Clínico APS: TRASTORNO TÉMPORO MANDIBULAR EN ATM DERECHA, BRUXISMO NOCTURNO Trastornos de la articulacion temporomaxilar',
#  'DISPLACIA DE CADERA EN CONTROL',
#  'arritmia en estudio hta en tratamiento obesidad',
#  'periodobntiis cronica generalizada severa. ( pcte DBT insulinorrequiriente, HTA)',
#  'enfermedad renal vcronica etapa 4.5',
#  'cardiopatai acoronaria\nCRM\nobeso morbido\ndm2, apnea sueño',
#  'DESENTADA PARCIAL',
#  'NECESIDAD DE PROTESIS SUPERIOR',
#  'LUMBAGO NO ESPECIFICADO, ESCOLIOSIS NO ESPECIFICADA',
#  'PG ADOLESCENTE G2 PO A1 GESTACION 9/6 SEMANAS ARRITMIA CARDIACA, ESCOLIOSIS, SOBREPESO PIG 8 MESES',
#  'enfermedad d chagas  pcte. con antecedente de enf. de chagas  diagnosticado el año 2001, fue operado hace 2 años por estenosis esofagiga? y de ulcera peptica operada a los 21 años. actualmente con disminucion del apetito y baja de peso de +- 5 kilos.asin',
#  'ENFERMEDAD POLIQUISTICO RENAL Y HEPATICA.',
#  'desdentado pracial',
#  'metastasis hepatica en controlde ca al colon operado',
#  'pza 30 pulpitis',
#  'herida por perdigones mano izquierda',
#  'PACIENTE   DESDENTADA   TOTAL  SUPERIOR    E  INFERIOR',
#  '- HIPOACUSIA, NO ESPECIFICADA/  - Fundamento Clínico APS: acude por cuadro de disminucion de agudeza auditiva con audiograma que muestra deficit en oido derecho en bajas frecuencias Hipoacusia, no especificada',
#  'CARDIOPATIA CORONARIA INFARTO ANTIGUO',
#  'TRATAMIENTO RADICULAR PIEZA 1.3',
#  'P.D 4.3 PERIODONTITIS APICAL CRONICA. RX PERIAPICAL',
#  'SEGUIMIENTO Y TTO',
#  'lesion en paladar estudio',
#  'EVALUACION DE NODULO CUTANEO',
#  'Hipoplasia Ventriculo Izquierdo',
#  'MORDIDA INVERTIDA SEVERA OVERJET 6 MM',
#  'amigdalitis a repeticion - cx amigdalectomia + rrf+colleras',
#  'NODULO PULMONAR A DESCARTAR',
#  'LIPOMA HEMIABDIMEN SUPEROR DRECHO, LIPOMA LUMBAR',
#  'PULPA NO VITAL EN ESTADO AGUDO CON PRESENCIA Y FISTULA',
#  'PACIENTE DESTENTADA PARCIAL SUPERIOR E INFERIOR CON PROTESIS DESAJUSTADAS',
#  'DOLOR ANAL CRONICO SINDROME DEPRESIVO',
#  'Obs Vicio de refracción.',
#  'fx flector l2 antigua',
#  'PACIENTE PRESENTA PERIODONTITIS LOCALIZADO EN GRUPO II PACIENTE DESDENTADO PARCIAL',
#  'traumatismo superficial de otras partes de la cabeza',
#  'pcte. con lipoma',
#  'VICIO DE REFRACCION SOSPECHA DE ECTASIA CORNEAL',
#  'PACIENTE DENTICION MIXTA 2° FASE APIÑAMIENTO DENTARIO',
#  'PACIENTE DESDENTADO PARCIAL SUPERIOR E INFERIOR, PERIODONTITISCRONICA MODERADA, CARIES, ABFRACCIONES, PORTADOR DE PROTESIS REMOVIBLE SUPERIOR.',
#  'MULTIPARA DE 1 EMBARAZO 18 SEMANAS HIPERTIROIDISMO',
#  'APUÑAMIENTO ANTERO INFERIOR LEVE FALTA ESPACIO PZA 6 Y 22',
#  'dte 6 caries profunda y cercana a entrada de conducto',
#  'PERIODONTITIS  CRONICA   GENERALIZADA',
#  'pieza 4 ausente , sin funcionalidad ocuosal correcto espacios medio, distal anatomico y linea oclusal sin invasion',
#  'Paciente Con Deficit Atencional',
#  'LUMBAGO CICTRALGIA',
#  'pieza 12 caries dentinarias profunda. pieza 4 caries dentinaria profunda.',
#  'tr, personalidad, intento de suicidio, vif, consumo riesgozo de alcohol',
#  'OTRAS EMBOLIAS Y TROMBOSIS VENOSA PROFUNDA PIERNA IZQUIERDA EN TT  CON  TACO',
#  'colestiacia embarazo 33+3 multipara',
#  '5tda diente permanente pza 5.1 y 6.1',
#  'RINITIS ALERGIA (DERIVADO DE LA JUNAEB)',
#  'EXAMEN ODONTOLOGICO Paciente desdentado parcial superior e inferior. Se deriva para evaluación y confeccio´n de PPR sup e inf',
#  'se solicita evaluacion y tratamiento en pieza 8 y9',
#  'NEVO BENIGNO',
#  'HIPOACUSIA BILATERAL. APP: HTA EN TTO.',
#  '_ ULCERA VENOSA PIERNA DERCHA.',
#  'HIPERQUERATOSIS EN PALMA Y PLANTA SEVERA.',
#  'Desdentada parcial superior e inferior, clase IV kennedy superior y clase II kennedy inferior',
#  'AGENESIA INCISIVOS CENTRALES INFERIORES',
#  'Desdentada superior inferior',
#  'QUERATOPATIA OCUPACIONAL',
#  '- DESDENTADO PARCIAL/  - Fundamento Clínico APS: clase II SUB 3 superior. clase I inferior. Otras afecciones especificadas de los dientes y de sus estructuras de sosten',
#  'HEMORROIDES INTERNAS NO COMPLICADAS, HTA',
#  'TUMOR MALIGNO PAPILAR DEL MESOTELIO DAÑO HEPATICO CRONICO CHILD-A',
#  'CEGUERA DE UN OJO - H04.1 OTROS TRASTORNOS DE LA GLNNDULA LAGRIMALojo seco',
#  'PERIODONTITIS  PIEZAS 7 Y 10 CARIES  DENTARIA PROFUNDA',
#  'LIPOMA DORSAL GIGANTE, TEP RECUPERADO',
#  'presenta pieza 4.7 con caries odlv destruccion coronaria extensa  se indica exodoncia en rx se observa pieza 4.8 incluida en posicion horizontal impactada con pieza 4.7',
#  'Paciente presenta TEC cerrado el 13/11/16 + fractura de cráneo. Queda hospitalizado por 3 días. Trae un comprobante de atención no epicrisis con solicitud de derivar a neurología a través de cesfam. Persiste con cefalea, nauseas. convulsiones: no sin vomitos.',
#  'RN PT 36 SEM AEG',
#  'D.M tipo II',
#  'TRASTORNO OPOCIONISTA',
#  'OBS. HIPOTEMIA - CRISI CONVULSIVA?',
#  'OH CRONICO ACTIVO ( HEPATITIS OH)',
#  'FRENECTOMIA LINGUAL DERIVADO DESDE FONOAUDIOLOGO',
#  'neuroftalmo',
#  'PZA 4 Y 13 SE SOLICITA EXODONCIA',
#  'DG: CANCER DE RECTO',
#  'Z01.2 INDICACIÓN DE ORTODONCIA',
#  'presencia de torus palatino irregular asintomatico',
#  'falta espacio erupción piezas 7 y 10 , retenidas',
#  'PTE CON PERIODONTITIS CRONICA GENERALIZADA SEVERAN.',
#  'L64.9 ALOPECIA ANDROGENA, NO ESPECIFICADA',
#  'bruxismo-dolor art.temporomandibular',
#  'PIEZA 4.6 PILPITIS IRREVERSIBLE',
#  'NEVU EN CARA SINTEMATICO',
#  '- Dientes incluidos e impactados\n - Anomalías dentofaciales incluso la maloclusión\n - Otros trastornos de los dientes y de sus estructuras de sostén:\nTU ODONTOGENICO MANDIBULAR IZQUIERDO QUE PROVOCA RETENCION PIEZA 31',
#  'OBS. EPILEPSIA CRISIS DE AUSENCIA.',
#  '- DESDENTADO PARCIAL MAXILAR Y MANDIBULAR - TRATAMIENTO OPERATORIO TERMINADO - TRATAMIENTO PREVENTIVO TERMINADO',
#  '- Obs Infeccion Protesis De Cadera Derecha',
#  'Ca Mama D? hora Psicologa',
#  'piezas 2 y 6 caries profundas pulpitos irreversible',
#  'TDA DIENTES 8-9',
#  'PZA. 1.5 CARIES PENETRANTE,',
#  '- PTERIGION/  - Fundamento Clínico APS: I.C. UAPO: DISMINUCION AV PL Y PC  AMETROPIA',
#  'pcte con DM y HTA bajo tto. Periodontitis crónica severa en todas las piezas. Desdentada parcial maxilar y mandibular portadora de protesis acrílica hace 4 años. Se trata con metronidazol y amoxicilina 500mg 1 c/8x7 días, se realiza destartraje, educación',
#  'PACIENTE DESDENTADA PARCIAL MANDIBULAR, SE SOLICITA CONFECCION DE PROTESIS INFERIOR PARCIAL',
#  'Desdentada parcial superior e inferior, con interconsulta para PFS de pieza 2.1, con necesidad de realizar previamente protesis parcial sup e inferior',
#  'PRSF MITRAL SEVERA',
#  'K432 HERNIA INCISIONAL SIN OBSTRUCCIÓN O GANGRENA PACIENTE CON HERNIA INCISIONAL ABDOMINAL QUE HA IDO AUMENTANDO DE TAMAÑO, REDUCIBLE, SIN SIGNOS DE COMPLICACIÓN  ACTUALMENTE DE UNOS 5 CM DE DIÁMETRO  SE SOLICITA EVALUACIÓN POR ESPECIALISTA',
#  'PD 2.3 CARIES OD PROFUNDA, PULPITIS IRREVERSIBLE',
#  'HIPERMELANOSIS FACIAL',
#  '- OTRAS OTITIS MEDIAS CRÓNICAS NO SUPURATIVAS/  - Fundamento Clínico APS: vertigos desde hace 10 dias, EF: CAE permeables, se evidencia membrana timpanica con exudado purulento, MTD impresiona rota, refiere hipoacusia derecha de larga data. Otras otitis medias cronicas no supurativas',
#  'M1 - INCONTINENCIA URINARIA- PROLAPSO VAGINAL',
#  'FRACTURA DE FALANGE DEL DEDO INDICE',
#  'Terceros molar 1.8 incluido- 2.8 bajo plano oclusal- 4.8-3.8 En evoluci??n extraosea y en mesioversi??n (Proyectadas en conducto dentarios)',
#  'DM2.HTA. DLP. INCONTINENCIA AO',
#  'Bocio multinodular op.',
#  'marcha equina.',
#  '- MAL OCLUSION',
#  'CICLOS IRREGULARES',
#  'ADICCION EN TTO.',
#  '- EDENTADA TOTAL SUPERIOR - EDENTADA PARCIAL INFERIOR',
#  'ROTURA COMPLEJA DE MENISCO INTERNO CONDROPATIA DEGENERATIVA.',
#  'AUSENCIA ULTIMAS COSTILLAS DERECHAS',
#  '-PULPITIS IRREVERSIBLE PIEZA 2.5 PIEZA TRAPANADA',
#  'm2 doble  cesarea  anterior emb  36 + 2 semanas feto grande  eg  (diag  prev  de aro) permitio   extremidades  inferior  nocturno',
#  'RETRACCIÓN GINGIVAL',
#  'PIEZA 1.3 SEMI INCLUIDA',
#  'EPILEPSIA -',
#  'G473 APNEA DEL SUEÑO RONQUIDOS, SOMNOLIENCIA DIURNA  DHC CHILD A X OH',
#  'DIENTE NUEVO ABSCESO DENTOALVEOLAR AGUDO.',
#  'O601 TRABAJO DE PARTO PREMATURO ESPONTÁNEO CON PARTO PREMATURO NEVUS PILOSO PARIETAL DERECHO',
#  'Espacio inferior disminuido Mordida abierta anterior.',
#  'RUIDO ARTICULAR EN APERTURA ATM DERECHA, SE SOLICITA EVALUACION PARA PLANO DE RELAJACION',
#  'ABSESO SUBMUCOSO.',
#  'macoclusion',
#  'D04-Carcinoma in situ de la piel',
#  '¿ENFERMEDAD PERIODONTAL?',
#  'PIEZA 9 CON TRATAMIENTO PROTESICO MEDIANTE PROTESIS FIJA UNITARIA DESADAPTADA',
#  'PZA 32 17 SEMIINCLUIDA',
#  'TRASTORNO DEL LENGUAJE MIXTO SEVEROOBS HIPOACUSIA',
#  '- TRASTORNO DE LA FUNCIÓN VESTIBULAR, NO ESPECIFICADO/  - Fundamento Clínico APS: paciente con cuadro de aprox 1 año de evolución, presenta sensación de vértigo  en asociación  de tinnitus que le precede. duración de pocos minutos ( 5 aprox) que inicia en reposo y en ocasiones con cambios posturales.  no refiere pérdida de audición. sin vómitos. otoscopía normal. romberg y unterberger fukuda normal.   solicito evaluación y manejo.  Trastorno de la funcion vestibular, no especificado',
#  'OBS PCTE DESDENTADA PARCIAL SUP E INF CON PPR SUP E INF DESAJUSTADAS CON 10 ANOS DE ANTIGUEDAD RELATA  PCTE',
#  'E.P.D. TIPO FIBROTICA SIN ETIOLOGIA PRECISADA SE ENVIA PARA EVALUACION DE ENFERMDAD DEL TEJIO CONECTIVO CON DAÑO PULMONAR',
#  'DISFUNCION\xa0SEXUAL\xa0NO\xa0OCASIONADA\xa0POR\xa0TRAST.\xa0NI\xa0POR\xa0ENF.\xa0ORGANICOS,\xa0NO\xa0ESPECIFICADA / PACIENTE\xa0CON\xa0DISFUNCIÓN\xa0ERECTIL\xa0DE\xa03\xa0MESES\xa0DE\xa0EVOLUCIÓN',
#  'NEUROPATIA MOTORA DISTAL HEREDITARIA (dhmn)',
#  'Diente 1.4 presenta obturación coronaria infiltrada con relleno endodóntico parcialmente expuesto al medio oral, radiográficamente presenta lesión apical.',
#  'OBS CUERPO EXTRA?O MANO IZQ',
#  'Artrosis De Cadera.',
#  'Caries de cubito por pieza 4.8 semierupcionada',
#  'GENALGIA EN ESTUDIO PIE PLANO G II',
#  'Obs: Adenomiosis.',
#  'PIEZA 8 PALATINIZADA, COMPRESION MAXILAR',
#  'onesidad grado ii',
#  'Periodontitis avanzada PFP (8-910)',
#  'm1,diu incrustado',
#  'Hernia inguinal - derecha - Hernia inguinal',
#  'MOLARES INFERIORES CON CARIES EXTENSAS , PULPITIS IRREVERSIBLE',
#  'CONTROL DE POLIPOS',
#  'Macula  Hiperpigmentada',
#  'PACIENTE DESDENTADA PARCIAL SUPERIOR E INFERIOR SOLICITO REALIZAR TTO PROTESIS REMOVIBLE POR ESPECIALISTA',
#  'obs. tendinitis manguito rotador',
#  'EDENTADO PARCIAL MAXILAR,TOTAL MANDIBULAR.',
#  'Desajuste De PrNtesis - HipNtesis DiagnNstica protesis removible superior desajustada',
#  'pac bruxomano',
#  'PROTOCOLO DE INGRESO PRE- TRASPLANTE RENAL',
#  'paciente denticion mixta 1ra fase  presenta insercion de frenillo labial baja se solicita evaluacion',
#  'PACIENTE 68 AÑOS ,ANTECEDENTES MEDICOS DE RESISTENCIA A LA INSULINA ,RELATA SUFRIR APUNTE DENTARIO CONSTANTE ASICIADO A DOLOR DE CABEZA AGUDO BILATERAL HACE 5 AÑOS . A CONSULTADO CON MEDICO ANTERIORMENTE ,PRESENTA INDICACION DE MEDICAMENTO TENSIMEX (1 CAD',
#  'CIRUGIA TERCEROS MOLARES  PZA 17 -32',
#  'PACIENTE EDENTADO PARCIAL SUPERIOR E INFERIOR',
#  '- CARIES DENTINARIA PENETRANTE/  - Fundamento Clínico APS: PACIENTE 30 AÑOS SIN ANTECED. MEDICOS PRESENTA CARIES PROFUNDA CAVITADA CON SINTOMATOLOGIAS, SE REALIZA TREPANACION, SE DERIVA A EVALUACION Y POSIBILIDAD DE TRATAMIENTO Caries del cemento',
#  'LESION ASPECTO SEBORREICO UNICO CUERO CABELLUDO',
#  'S92.1      FRACTURA DEL ASTRAGALO',
#  'PCTE PORTADORA DE A. REUMATOIDEA SECUELADA CON HTA SIN TTO. SIN CONTROL DMII CON MAL MANEJOOBS. INSUFICIENCIA CARDIACASE SOLICITA FAVOR EVALUACION Y MANEJO',
#  'HERNIA UMBILICAL. DM2. HTA. COAGULOPATIA',
#  'epitaxis nasal izquierdo',
#  'ARTROSIS CARDERA D OPERADA HACE UN MES',
#  'P.16 NO ERUPCIONADA. P.17 SEMIERUPCIONADA, PERICORONARITIS A REPETICION P0. P.32 SEMIERUPCIONADA. SOLICITO POSIBILIDAD DE EXODONCIA, P.17 PRIORIDAD O. RX. PANORAMICA EN PODER DEL PACIENTE.',
#  'HOLTER ARRITMIA OBS. BLOQUEO ALTO GRADO HTA DLP',
#  'obesidad morbida hta dm2 apnea del sueño',
#  'p 19 trart endodonticamente',
#  'T. CONDUCTA T. DEFICIT ATENCIONAL CON HIPERACTIVIDAD',
#  'periodontitis aguda pza. 12',
#  'PIEZA 11 FRACTURA CORONARIA TRATADA ENDODONTICAMENTE',
#  'PIEZA 1.6 TRATADA ENDODONTICAMENTE REHABILITADA CON ONLAY ESTETICO OM GRANULOMA APICAL RAIZ MESIAL PD 2.8 SEMIINCLUIDA RAICES PROXIMAS.',
#  'M2 Partos normales Usuaria ACO PROGEST',
#  'paciente fue derivada a patologia mamariaaparicion  de pilota mama derechaen el examen se aprecia masa solida movil en el csila eco arroja nodulo solido de aspecto indeterminado',
#  'DESDENTADA TOTAL MAXILAR Y PARCIAL MAND.',
#  'AGENESIA PIEZA DENTAL 24,25 ( PERSISTENCIA PIEZA DENTAL O - P )',
#  'PACIENTE PRESENTA CARIES PROFUNDA PIEZA 2.2,',
#  'TROMBOSIS SENO VENOSO EXTENSO',
#  'M4 Pólipo Endometrial 20x14 mm',
#  'TUMOR DE HIPOFARINGE',
#  'DESDENTADO TOTAL INFERIOR - SIN PROTESIS',
#  'DTE. 1.5 CARIE OCLUSOMESIAL PROFUNDA.',
#  'ANT.DE CA MAMAS OPERADO',
#  'Dm-1',
#  'paciente desden tado parcial superior e inferior',
#  'VICIO REFRACCION DM2 NIR',
#  'TEC COMPLICADO FRACTURA OCCIPITAL Dº',
#  'INESTABILIDAD DE LA MARCHA  - HACE 3 SEMANAS SE CAE  - RAQUIESTENOSIS LUMBAR',
#  'PROTESIS REMOVIBLE TOTAL SUPERIOR, PARCIAL INFERIOR.',
#  'Hipertrofia genital. Labios externos.',
#  'ALTERACION ORDEN DENTARIO',
#  'vertigo , hipoacusia',
#  'M1 OBS. COLPOCELE Quiste anexial izquierdo x ECO',
#  'ANOMALIAS DENTOFACIALE',
#  'pcte desdentada total superior he inferior con epulis en zona grupo 5',
#  'amigdalitis cronica - amigdalectomia',
#  '-MASA CERVICAL A ESTUDIO',
#  'paciente embarazada, sin antecedentes medico relevantes. desdentada parcial superior clase iii kennedy',
#  'Desdentada total superior ,parcial inferior',
#  'Periodontitis Aguda Pza 32.',
#  'PACIENTE CON APIÑAMIENTO DENTARIO INTERNO SUPERIOR Y COMPRESION MAXILAR',
#  'DESORDEN  TEMPOROMAN. OROFACIAL, SALTO Y ASINCRONIA ARTICULAR',
#  'Diente 14 con pulpitis irreversible, con terapia previamente iniciada.',
#  'N18.1      ENFERMEDAD RENAL CRONICA, ESTADIO 1',
#  'DOLOR AB.RECURRENTE',
#  'DIPLOPOA   - HTA',
#  'MENINGIOMA FOSA TEMPORAL',
#  'PG. EGD SOSP RCIU',
#  'Coledocolitiasis Colecistectomizada Hernia incisional no complicada Hipertencion arterial cronica.',
#  'apiñaminto antero superior',
#  '- AMIGDALITIS CRÓNICAAmigdalitis crónica    Diabetes IR, DLP, Hipertension en tratamiento LST 1 cada 12 hrs, NTD 1 cada 12 hrs , alergias no relata, cx no Refiere constante infalamacion y dolor amigdaliano, recurrentes episodios de amigdalitis durante el año. Halitosis, tos seca irritativa  Al examen fisico: Amigdalas grado 2-3  , tejido hipertrofico  de las amígdalas palatinas  Derivo para evaluacion y tratamiento  Atte',
#  'K076 TRASTORNOS DE LA ARTICULACION TEMPOROMAXILAR SE DEBE INSITIR EN QUE PACIENTE MASTIQUE MAS POR LADO DERECHO YA QUE TIENE DE HABITO MASTICAR POR EL LDAO IZQUIERDO.',
#  'SD AR TR POLIFARMANCIA',
#  'CARIES EN PUENTE DIFICIL',
#  'PZA 3.7 CON PULPITIS IRREVERSIBLE SINTOMATICA + OSTEITIS INTERRADICULAR , NO TREPANADA , PACIENTE MUY SINTOMATICO + PULPOLITO EN CORONA PULPAR',
#  '- PÉRDIDA DE DIENTES DEBIDA A ACCIDENTE, EXTRACCIÓN O ENFERMEDAD PERIODONTAL LOCAL/  - Fundamento Clínico APS: Paciente desdentado parcial, pierde dientes 1.1 y 2.1 por periodontitis Perdida de dientes debida a accidente, extraccion o enfermedad periodont',
#  'SEMINCLUIDO PIEZA 17',
#  'dda.c/r bilateral',
#  'HT ADENOAMIGDALAS SEVERA',
#  'terceros molares en evolucion intraosea',
#  'PROTESIS FIJA UNITARIA CON DESJUSTE PROXIMAL Y ARVICAL DE PIEZA DENTARIA 10.',
#  'DEFORMIDADES VALGUS GONGENITAS DE LOS PIES',
#  'Pza 3.8 semi incluida, pericoronaritis a repeticion',
#  'PULPITIS IRREVERSIBLE PZA 30-31',
#  'PZA 48',
#  'VARICES EEII BILATERAL ASMA',
#  'endodoncia p 19',
#  'OTROS TRASTORNOS DEL SISTEMA CIRCULATORIO EN ENFERMEDADES CLASIFICADAS EN OTRA PARTE',
#  'PERIONTITIS',
#  'POLIADICTO.',
#  'DIENTE 1.1 TREPANADO Y MEDICADO',
#  'caries dentinaria profunda pza 17 y 32',
#  'LESION FLEXO BRAQUIAL IZQ\xa0',
#  'lumbago izquierdo- quiste posterior de la rodilla izquierda',
#  'piezas 4-5 ausente',
#  '- VERRUGAS VIRICAS/  - Fundamento Clínico APS: PACIENTE CON VERRUGA EN PLANTA DE PIE DE LARGA DATA. REFIERE MOLESTIA Y DOLOR. SOLICITO EVALUACION POR ESPECIALIDAD. ATTE. Verrugas viricas',
#  'trepanación 4.5',
#  'PERIODONTITIS APICAL CRONICA 4.3 (PREVIO A TREPANACION)',
#  'PZ. 1.8',
#  'hipertrofia testiculo',
#  '- ANOMALIA DENTO MAXILAR - MORDIDA BIS A BIS',
#  'diseccion aortica tipo b hta',
#  'K07 ANOMALIAS DENTOFACIALES INCLUSOLA MALOCLUSION PACIENTE CLASE II OP DE CIRUGIA ORTOGNATICA',
#  'DESDENTADO TOTAL SUPERIOR PACIAL INFERIOR',
#  '- HEMORRAGIA GASTROINTESTINAL, NO ESPECIFICADA/  - Fundamento Clínico APS: hace +/- 2 meses con episodios de eliminacion de sangre osucra por boca, solo matinal, cada 15 dias, sin otros sintomas asociados. antecedente de gastrectomia subtotal hace +/- 30 años Hemorragia gastrointestinal, no especificada',
#  '- SUPERVISIÓN DE EMBARAZO DE ALTO RIESGO DEBIDO A PROBLEMAS SOCIALES/  - Fundamento Clínico APS: PRIMIGESTA EMB. DE 39 SEM. CONDILOMATOSIS???',
#  'PIEZA 18  TREPANADA PIEZA 30CARIES PENETRANTES',
#  'GM 10, OBS. CA DE ENDOMETRIO, ENDOMETRIO ENGROSADO, SIN HEMORRAGIA, DOLOR SACRO',
#  '- TRASTORNOS DE LA ARTICULACIÓN TEMPOROMAXILAR/  - Fundamento Clínico APS: Ppaciente con dolor cronico articular del lado derecho que se intensifica al  morder. Se solicito rx panoramica y se encuentra una zona radiopaca difusa a nivel del condilo derecho',
#  'DOLOR RECURRENTE CIRUGIA DE CESAREA HACE 5 MESE NO CEDE CON USO DE ANALGESICOS ACTUALMENTE SIN RASGOS DE INFECCION M HERIDA LIMPIA , NO CONTENIDO PURULENTO',
#  'caries profunda 32  sintomatica dolor evaluacion  posibilidad de exodoncia',
#  'R51X CEFALEA PACIENTE CON CEFALEA QUE HA IDO EN AUMENTO  SE DESCARTA CAUSA RINOGPENICA',
#  'H509 ESTRABISMO, NO ESPECIFICADO EXAMEN DEMUESTRA ESTRABISMO DESNUTRICION EN ESTUDIO',
#  'PZA  8  TRATADA ENDODONTICAMENTE CON GRAN DESTRUCCION CORONARIA',
#  'pza 13 tratada endodonticamente con pfu larga data. preparacion con caries cervical. se sol volver a realizar pfu',
#  'pieza 7 con sistema perno muNNn, requiere prNtesis fija unitaria',
#  'Period cronica gralizada mod av. Pase pre QMT.',
#  'sd bronquial obstructivo a repetición',
#  'OTITIS MEDIA CRONICA DEL OIDO IZQUIERDO.',
#  'H54.0 - CEGUERA DE AMBOS OJOS / CEGUERA DE AMBOS OJOS',
#  'CHALAZION PARPADO DERECHO SUPERIOR',
#  'ABSCESO DENTOALVEOLAR AGUDO EN RELACION A PIEZA 3.6.',
#  'SOPLO SISTOLICO FOCO AORTICO SIN IRRADIACION II/VI',
#  'HRC HIPERTENSIVA',
#  'RET URINARIA',
#  'Lesion menisco (rodilla) interno nc - izquierdo/a',
#  'PULPITIS PIEZA 2.6 Y 2.7',
#  'Apiñamiento dentario.',
#  'dte 3.7 rest penetrante.',
#  'ERITEMA NODOSO.',
#  'PACIENTE SANO  ¿HIPERTROFIA VENTRICULAR?',
#  'Hipermetrpía+Astigmatismo',
#  'periodentitis cronea avanzada generalizada',
#  'PIEZA 19 PULPITIS IRREVERSIBLE, TREPANADA',
#  'PARPADO DERECHO INFERIOR INFLAMADO',
#  'se solicita exodoncia de 4 tercerod molares piezas 1-16-17-32',
#  'PACIENTE DESDENTADA TOTAL SUPERIOR Y PARCIAL INFERIOR ( POSTERIOR BILATERAL )',
#  'ANTECEDENTE DE TREPANACION',
#  'SOSP FRACTURA ACETABULAR',
#  'mesiodens superior apiñamiento anter-',
#  'HNP cervical C6-C7. Artrosis cervical moderada.',
#  'HIPERMENORREA EN ESTUDIO CA MAMA IZQUIERDA EN TRATAMIENTO',
#  'APNEAS DURANTE LAS NOCHES MÀS RONQUIDOS. OBESIDAD, HTA,',
#  'DISCOPATIA, L3, L4, L5, Y L5 CAMBIOS DEGENERATIVOS FACETARIOS DOLOR MANTENIDO EN COLUMNA LUMBOSAGRO, CONSTRACTURA MUSCULAR PARABERTEBRAL',
#  '*FALTA ESPACIO PRE-MOLARES INFERIORES *APIÑAMIENTO DENTARIO',
#  '- CARIES DENTINARIA PENETRANTE/  - Fundamento Clínico APS: 1.4 trepanada  Caries del cemento',
#  'PIEZA  17  Y 32 SEMIERUPCIONADA - SOLICITO  EXODONCIA    AMBAS  PIEZAS',
#  'diente 2.1 trepanada.',
#  'G2P0A1, EMB 17+3, DOPPLER ARTERIAS UTERINAS ALTERADO',
#  'FRENILLO BUCAL INSERCION BAJA DIASTEMA PZA 8 - 9 SOLICITO EVALUACION Y POSIBILIDAD DE TTO',
#  'SOLICITO EXODONCIA PZA 32',
#  'MUCOCELE LABIAL INFERIOR POR EXTRAVASACIÓN',
#  'DIENTES INCLUIDOS E IMPACTADOS, PIEZA 3.8',
#  'd.d.m.con apiñamiento severo',
#  'Pericoronaritis Parte O Pieza 1',
#  'soplo cardiaco.',
#  'lesión menisco interno rodilla izquierda',
#  'Pcte presenta multiples desgastes oclusales, abfracciones cervicales y erosiones palatinas. se solicita evaluar por bruxismo y tto.',
#  'HERNIA ABDOMINAL RECIDIVANTE',
#  'QUISTE RENAL DERECHO NEFROPATIA IZQUIERDA',
#  'ASTRALGIA DE RODILLAS',
#  'DOLOR ATM POSTERIOR A TRAUMA FACIAL',
#  'NODULO AXILAR DERECHO.',
#  'PROTESIS REMOVIBLE PARCIAL SUP E INFER.',
#  'MASA CERVICAL (LIPOMA REGION CERVICAL POSTERIOR)',
#  'PIEZA # 4.8 SEMIENCLUIDA',
#  '- ANOMALÍAS DENTOFACIALES (INCLUSO LA MALOCLUSIÓN)/  - Fundamento Clínico APS: paciente presenta apiñamiento dentario inferior. mordida abierta anterior. Malposiciones dentarias en maxilar superior. Anomalias dentofaciales (incluso la maloclusion)',
#  'Antecedente TEC complicado operado (hematoma extradural) Trastorno de la memoria a corto plazo Estenosis subglótica',
#  'G2 P0 A1 EMB 11+6 SEM OBS HTA',
#  'refiere control dental por profilaxis . protesis aortica biologica',
#  'caries pza 10',
#  'inicio de uso hidroxicloroquina vicio refraccion presbicia',
#  'DIENTE 4.5 TREPANADO',
#  'Orina Olor Malo',
#  'Disfunción ATM ( Bruxismo)',
#  'ENDODONCIA PIEZA 3.6 Y 4.6',
#  'PAC. 56 AÑOS , DESDENTADA TOTAL SUP. E INF.',
#  'OTROS AGENTES PRINCIPALMENTE SISTEMICOS Y HEMATOLOGICOS / OTROS AGENTES PRINCIPALMENTE SISTEMICOS Y HEMATOLOGICOS',
#  'pieza 30 incluido con proceso infeccioso',
#  'DIENTE 3.5 DESTRUCCION CORONARIA EXTENSA TRATADA ENDODONTICAMENTE.',
#  'G2 P1 AO V1 EMBARAZO 27+2 CCA X SFA',
#  'polipo endomertrial',
#  'CARIES DENTINARIA PENETRANTE, CARIES EXTENSA EN PZA 1.7',
#  '- DEMENCIA EN LA ENFERMEDAD DE ALZHEIMER (G30+)/  - Fundamento Clínico APS: Paciente inicia desde el 2012 con cuadro de deterioro cognitivo y de memoria a corto y largo plazo, manteniedose con pequeña evolutividad hasta la fecha. Se aplica minimental test con puntaje de 22 puntos. Destaca ademas sintomatologia depresiva sin factor gatillante que recuerde la paciente, la cual se está tratando con sertralina 150 mg/dia.  Solicito evaluacion por especialista Demencia en la enfermedad de Alzheimer (G30+)',
#  'HIPERTROMIA ADENOIDEA',
#  'periododntitis marginal cronica',
#  'INSULINO RESISTENCIA. PSORIASIS.',
#  'VARICES GRADO II PIERNA IZQUIERDA',
#  'rutomaxillar por ¿compresión?',
#  'Periodontitis Dm 1',
#  'EXAMEN ODONTOLOGICO, p 1.5 trepanada',
#  'SD METABOLICO / INSULINORESISTENCIA/ OBESIDAD',
#  'Paciente con tuberculosis extra pulmonar',
#  'G5 P5 A0 paridad Cumplidausuaria Desea Esterilizaci?n Quir?rgica.',
#  'ARTROSIS RODILLA SEVERA Y MANOS',
#  'exantema viral? rash alergico?',
#  'diag mordida abierta anterior,supernumerario pzas temporales',
#  'desdentado parcial bimaxilar Kennedy lll superior y Kennedy ll 1 inferior',
#  'Trastorno del desarrollo psicosexual, no especificado',
#  'FRACTURA INCOMPLETA O FISURA SALTER HARRIS GRADO II DEL BASE FALANGE PROXIMAL DEL 5° DEDO IZQUIERDO.',
#  'USUARIA SIN PATOLOGIAS CRONICA, POLICARIES, GINGIVITIS GENERALIZADA MODERADA, PIEZA 7 CARIES PROFUNDA',
#  'pza 09 fractura radicular,  indicaciNn P implante.',
#  'NECROSIS PULPAR PIEZA 1.1 TREPANADA',
#  'TDO PZA. 10, FRACTURA CORONARIA COMPLETA PZA. 10',
#  'PZA 17-32 SEMIINLUIDAS',
#  'EXODONCIA PIEZA 10',
#  'pieza 1.2(7) presenta fractura coronal, se realiza resina provisoria pieza 7. solicito favor evaluar tto. rehabilitador fija por especialista.',
#  'ANGINA INESTABLE A OBSERVAR - ICC ISOSORBIDE 10 MG 1-1 FRS 20 MG X DIA - HTA AAS 100 MG 1X 1 NIFEDIPINO 20 MG ENL 2-2 DM2 GLIBENGLAMIDA 5 MG 1-0-1 MTF 850 1-1-1',
#  '- NECROSIS DE LA PULPA/  - Fundamento Clínico APS: 2.1 trepanada Necrosis de la pulpa',
#  'Dermatitis de contacto por irritantes, debida a otros productos quimicos',
#  'DIABETES MELLITUA¡S TIPO 2 IR HIPERTENCION ARTERIAL',
#  'PATOLOGIA GLANDULA SALIVAL MAYOR (RANULA? )',
#  'DESDENTADA PARCIAL SUPERIOR E INFERIOR .   BRUCISMO SEVERO',
#  'terceros molares 1-17-32',
#  '- SENO Y QUISTE PREAURICULAR/  - Fundamento Clínico APS: paciente de 15 años, acude con lesion preauricular derecha en region del trago de 1 año de evolucion que fue evaluada por ORL la cual solicita eco partes blandas en las que se evidencia lesion quistica de contenido denso en tragus derecho dermico subdermico de 10.3mm de diametro mayor. sin vascularizacion significativa. se observa coloracion violacea circundante, doloroso de forma ocasional se deriva por solicitud de ORL.  Seno y quiste preauricular',
#  'GASTRITIS EN ESTUDIO COLECISTECMIZADA',
#  'HIPOACUSIA BILATERAL,SINDROME VERTIGINOSO,HTA,DM II ,TABAQUISMO,DISLIPIDEMIA',
#  'PREMOLARES IMPACTADOS',
#  '- RETINOPATÍA DIABÉTICA/ - DIABETES MELLITUS, NO ESPECIFICADA/ - HIPERTENSIÓN ESENCIAL (PRIMARIA)/  - Fundamento Clínico APS: Paciente de 59 años, antec de DM2, HTA Evaluada por Oftalmologo externo:Informe Retinográfico:- Por medio de la evaluación realiz',
#  'TUMOR DE CUELLO UTERINO',
#  'PACIENTE DESDENTADO PARCIAL SUPERIOR Y PARCIAL INFERIOR.',
#  'QUISTE DE ASPECTO FUNCIONAL OVARIO IZQUIERDO',
#  'SECRECION PEZON',
#  'Pieza 1.5 Trepanada',
#  'PZ 19 TREPANADA POR PERIODONTITIS APICAL AGUDA',
#  '1.-M2A0. 2.- OBS. QUISTES MAMARIOS IZQ.',
#  'ENFERMEDADES DE LAS GLÁNDULAS SALIVALES',
#  '- PIEZA 1.2 2.2 RETENIDO POR FALTA DE ESPECIO, PIEZA 1.1 2.1 DISTALIZADA APIÑAMIENTO GRUPO V',
#  'paciente con controles psiquiatricos entratamientom con clorpromazina de 25mg por noche masaldol 1mg por noche',
#  '- HIPOACUSIA NEUROSENSORIAL, SIN OTRA ESPECIFICACIÓN/  - Fundamento Clínico APS: PACIENTE CON HIPOACUSIA > A DERECHA. SE DERIVA A CONTROL POR GES',
#  'BURSITIS PRERROTULIANA',
#  'fractura a nivel del tercio accidente escolar.',
#  'NEO DEL PULMON',
#  'PIEZAS 1,8, 2,8, 4.8 INCLUIDAS',
#  'ANEMIAS DE DEFICIENCIA DE HIERRO',
#  'pieza 13 con sintomatología dolorosa.',
#  'VARICES DE EXTREMIDADES INFERIORES INSUFICIENCIA VENOSA CRONICA',
#  'edentua total superior e inferior',
#  'K297 GASTRITIS, NO ESPECIFICADA PACIENTE PRESENTA HACE 5 HORAS DOLOR EN EPIGASTRIO ACOMPAÑADO DE VÓMITOS POSTPRANDIALES  COMENTA QUE PERIODICAMENTE PRESENTA ESTOS SINTOMAS Y SE RELACIONAN CON LAS COMIDAS',
#  'ENFERMEDAD ARTERIAL DE LOS MIEMBROS INFERIORES  DM IR  BALONPLASTIA MITRAL  FIBRILACIÓN AURICULAR PE',
#  'Pulpitis irreversible sintomática pza2.3.',
#  'Desdentada total Protesis dentales sueltas',
#  'P.17 INCLUIDA, EN MESIOVERSION. P.32 SEMIINCLUIDA. DISTALIZADA. SOLICITO REALIZAR EXODONCIA P.17 Y 32 POR INDICACINN ORTODONCIA.',
#  'Sinovitis Transitoria Cadera D?enf. De Perthes Inicial ?',
#  'OBS. DEMENCIA , HTA + DM 2 , HIPOACUSIA MAS MENOS 3 AÑOS PRESENTA DETERIORO MEMORIA ,SIN SINTOMAS DEPRESIVOS',
#  'hipotiroidismo detectado en embarazo . m1 adolescente. puerpera 35 días.',
# ...
#  'EXAMEN ODONTOLOGICO. Paciente desdentado parcial superior e inferior. Se deriva para evaluar posibilidad de realizar PPR sup e inferior.',
#  'TRASTORNO ANSIEDAD, OBESIDAD',
#  'Canino semiincluido en paladar',
#  'CA MAMA IZQ. TRATADA',
#  'H70.9 - MASTOIDITIS, NO ESPECIFICADA / MASTOIDITIS, NO ESPECIFICADA',
#  'Nevus Pigmentado Labial Inferior',
#  'DOLOR DEL CODO',
#  'Patologia de Pie  Otra patolog¡a TRASTORNO  DE LA MARCHA',
#  'SCA CEST',
#  'PZA 3.8 RETENIDA (HALLAZGO RADIOGRAFICO)',
#  'PIEZA 2.1 ABSCESO DENTOALVEOLAR AGUDO',
#  'NECROSIS PULPOSA',
#  'ESPACIO INSUFICIENTE PARA EMPIDE CANINOS DIFERENTES.',
#  'Lesion En Lengua',
#  'PZA. 4 Y 10 DIENTE CON TERAPIA PERMANENTE INICIADA',
#  'quist ovario obs 8 cm',
#  'deficit ponderal',
#  'DESDENTADA MANDIBULAR',
#  '- ENFERMEDAD DE LOS MAXILARES, NO ESPECIFICADA/  - Fundamento Clínico APS: Paciente hipertensa, dislipidemica y con artrosis de rodilla, presenta aumento de volumen óseo indoloro en hueso alveolar de molares y premolares superiores derechos, la paciente r',
#  'PZA. 5 PERIODONTITIS APICAL SINTOMATICA.',
#  'PACIENTE CLASE I MOLAR DERECHA E IZQUIERDA MORDIDA INVERTIDA, LA CUAL ESTÁ OCASIONANDO MOVILIDAD EN INCISIVOS INFERIORES APIÑAMIENTO SEVERO DIFICULTAD PARA CONTROLAR HIGIENE DEBIDO AL APIÑAMIENTO DENTARIO',
#  'Borrosa, vision - derecho/a',
#  '- CARIES DENTINARIA PENETRANTE/  - Fundamento Clínico APS: pieza 3.6 trepanada, se deja con mota con pmcf.  posibilidad de rehabilitacion mediante corona e incrustacion.  Caries del cemento',
#  'PERDIDA DE MEMORIA / REPETICION CONSTANTE DE PALABRA',
#  'pza 28 evaluacion',
#  '- DESDENTADA PARCIAL bimaxilar',
#  'OBS. GANGRENA LOCALIZADA 2? ORTEJO IZQ. ISQUEMIA CRONICA EEII IZQ.',
#  'P 3 Y4 EN EVOLUCION',
#  'PACIENTE DENTICION MIXTA 2da. FASE DISCREPANCIA OSEA DENTARIA AUSENCIA DE ESPACIO ERUPCION CANINOS DEFINITIVOS, EN CONTROL DESDE 2013.',
#  '- DEFORMIDAD EN VALGO, NO CLASIFICADA EN OTRA PARTE Paciente de 12 años, con talla alta. Refiere que hace 2 años presenta desviaicon del eje, con dolor al',
#  'PIEZA 30 -> ABSCESO SUBMUCOSO TREPANADO',
#  'QUISTE SINOVIAL EN RELACION CON LA VAINA DEL TENDON EXTENSOR DEL DEDO MEDIO IZQUIERDO',
#  'HIPOACUSIA SEVERA OIDO IZQ.',
#  'EVALUACION PIEZAS 8-9 RETRATAMIENTO0',
#  '-TUMOR DE PARED ABDOMINAL EN ESTUDIO',
#  'recién nacido prematuro 27 semana hidrocefalia obtrutiva',
#  'PIEZA 2.5 EN POLADA, POSICION VERTICAL, RAIZ HACIA DESTAL.',
#  'tu ANEXIAL IZQ.',
#  'control de radiografia solocita diente 20 absceso submucoso con indicacion  de enddooncia raiz presenta dislaceracion cervical y lesion apical refraccion apical evidente diente no esta trepanado ya que paciente no presennta sintomatologia pulpar',
#  'DISMINUCION DE AGUDESA VISUAL.',
#  'PIEZA 4 FRACTURADA CORONARIA EXTENSA',
#  '2.2. TRATADA ENDODONTICAMNTE, FRACTURA CORONARIA TOTAL SE DFERIVA PARA EVALUAR Y REALIZAR TRATAMIENTO REHABILITADOR.',
#  'DIENTE 4.6 TRATADO ENDODONTICAMENTE',
#  'PIEZA 5',
#  'EXAMEN ODONTOLOGICO, PZA 2.6 DOLOR A PERCUSION , PERIODONTITIS APICAL CRONICA, NECROSIS PULPAR, EN RX, GRANULOMA APICAL',
#  'TRATAMIENTO ENDODONTICO EXPUESTO',
#  'Tr Conductual/hiperactividad',
#  'paciente desdentado parcial inferior se solicita realizar tratamiento de protesis',
#  'NODULOS PEQUENOS TIROIDEOS BILATERALES',
#  'HTA DM OBESIDAD',
#  '- MALOCLUSIÓN DE TIPO NO ESPECIFICADO/  - Fundamento Clínico APS: paciente clase I, apiñamiento severo anteroinferior , se solicita realizar tratamiento de ortodoncia. Maloclusion de tipo no especificado',
#  'dolor abd en est masa fii',
#  'ruptura timpanica iodo izq.',
#  'PIEZA 8 CON NECROSIS PULPAR ASEPTICA , TREPANADA',
#  'Varices III6 M5 I5.',
#  'PZA 4 OSTEITIS APICAL',
#  'PCTE. DESDENTADA TOTAL SUPERIOR E INFRIOR.',
#  'Onicocriptosis recurrente.',
#  'DESDENTADO PARCIAL BIMAXILAR MAXILAR SUPERIOR CLASE II DE KENNEDY MODIFICACION 1.  MAXILAR INFERIOR CLASE III DE KENNEDY MODIFICACION 2.',
#  'Refiere que desde septiembre, tras uso de rodillera en trabajo, comienza con parestesias en pierna izquierda constantes, sin irradiación. Consultó en octubre donde se pidieron exámenes que se encuentran en rangos normales. Además fue evaluado por cirujano',
#  'ERUPCION EDOPTICA DE CARIES SUPERIOR',
#  'SEQUEDAD MUCOSA NASAL',
#  'PD8 PRESENTO REABSORCION OSEA MARGINAL AVANZADA CARIES MESIO CERVICAL PIEZA DENTARIA TIENE INDICACION DE EXODONCIA PACIENTE ESTA CONSIENTE DE COSTO A CANCELAR POR IMPLANTE',
#  'DESDENTADO TOTAL SUPERIOR. DESDENTADA PARCIAL INFERIOR. CLASE KENNEDY II, MODIFICACION I.',
#  '- ESGUINCES Y TORCEDURAS DEL TOBILLO/  - Fundamento Clínico APS: PACIENTE DE 55 AÑOS, CON ANTECEDENTE DE GONARTROSIS. REFIERE INVERSION FORZADA DE PIE DERECHO , MOTIVO POR EL CUAL ACUDE A SERVICIO D EURGENCIAS HACE DOS MESES ATRAS APROXIMADAMENTE. EN S.U.',
#  'MAL OCLUSIÓN  DE TIPO NO ESPECIFICO',
#  'LIPOMA GRAN QEMADO MUSLO IZQ.',
#  'Otra patolog¡a ENFERMEDAD DIVERTICULAR DE AMBOS INTESTINOS',
#  'COLELITASIS (EPICRISIS)',
#  'DESTRUCCION CORONARIA 4,6',
#  '-EPIFORA -HIPERSENSIBILIDAD A LA LUZ',
#  'Desdenatda Parcial',
#  'FRACTURA EN TALLO VERDE RADIO DISTAL IZQUIERDO',
#  'GENU VALGO GENALGIA DERECHA',
#  'FISTURA',
#  'NEVUS PARPADO INFERIOR IZQ',
#  'PIEZA 9 PULPITIS',
#  'PACIENTE EN TTO. OPERATORIA POR MODULO JUNAEB CLASE II MOLAR , APIÑAMIENTO EN PIEZAS DENTALES MAXILARES Y MANDIBULAR. CANINO ECTOPICO (N° 10)',
#  'Roncopata- 6 A 7 Amigdalitis X A?o',
#  '- FISURA ANAL CRÓNICA/  - Fundamento Clínico APS: Paciente con antecedente de HTA y de fisura anal hace 3 años, consulta por perssitencia de dolor que ha aumentado en intensidad en ultimo tiempo, el que se exacerba posterior a defecacion, sin rectorragia ni sindrome de ano humedo asociado. Al examen físico no se evidencian lesiones anales externas. Solicito valoración clinica a nivel secundario. ATTE. Fisura anal cronica',
#  'pulpitis irreversible pieza 3.6',
#  'PACIENTE GENERO MASCULINO DE  13 ANOS , PRESENTA DIENTE SUPERNUMERARIO EN RELACION A PIEZA  8',
#  'microsomia facial derecha',
#  'G1 P0 A0 RMBARAZO 36 DIABETES GESTACIONAL',
#  'PULPITIS IRREVERSIBLE PZA 2.5 (TREPANADA)',
#  'cáncer de mama sangrado transvaginal',
#  'COXOARTROSIS DERECHA PRIMARIA SEVERA.',
#  'HEPATITIS AGUDA. EPILEPSIA',
#  'NECROSIS PULPAR PZA 2.6 (TREPANACION)',
#  'nefrolitiasis bilateral + pielo ectasia itu a repeticion',
#  'APIÑAMIENTO DENTARIO GRUPO 2 Y 4 .',
#  'pza 3.8 incluida - 4.8',
#  'RETRASO EN CIERRE DE FONTANELA POSTERIOR',
#  'pieza 12 periodontitis apical crónica',
#  'pza 1-17-32  semi incluidas',
#  'PIEZA DENTARIA CON CARIES DENTINARIA PROFUNDA, PULPITIS IRREVERSIBLE, TREPANADA.',
#  'ATROFIA HEPATICA DIFUSA',
#  '- desdentado parcial bimaxilar clase de Kennedy lll 2 maxilar y lll mandibular',
#  'G3P2 EMBARAZO 10+3 DIABETES MELLITUS PREEXISTENTE HIPEREMESIS RURALIDAD EXTREMA',
#  'condilomatosis genital. lesión en cuello uterino ¿ quiste nobath?',
#  'ERUPCION DE CANINOS',
#  'SD. CONVULSIVO HDA EN ESTUDIO',
#  'dentado parcial superior -inferior',
#  'epoc (salbutanol)',
#  'ENFRMEDAD PERIODENTAL AVANZADA AGRABADO POR DM',
#  'DM 2 HTA ANAUROSIS OD',
#  'PACIENTE EN TTO DONTOLOGICO PZA 29 EN NECESIDAD DE TTO ENDODONTICO . DG PERIODONTITIS APICAL CRONICA  ASINTOMATICA',
#  'tratamiento endodactico antiguo pieza 5 dolor a percusion',
#  'Litiasis Ureteral Izquierda + Hidronefrosis',
#  'AR SEVERA DE RODILLA PASE OP',
#  '- PERIODONTITIS CRÓNICA/  - Fundamento Clínico APS: rom moderada en grupo V. Periodontitis cronica',
#  'pza 1.7 lesion endoperiodontal',
#  'PACIENTE DESDENTADO PARCIAL .  PERIODONTITIS SEVERA , DIABETES TIPO I , HIPERTENSO.',
#  'PIEZA 32 INCLUIDA EN MESOVERSION',
#  'PACIENTE DESTENTADO PARCIAL SUP. E INF.',
#  'OBS. FR. SOLTER  ANTEBRAZO  IZDO.',
#  '- DESDENTADO PARCIAL/  - Fundamento Clínico APS: DESDENTADO PARCIAL SUPERIOR E INFERIOR.  Otras afecciones especificadas de los dientes y de sus estructuras de sosten',
#  'Cicatriz U Opacidad De La Cornea',
#  'EN ELOB HIPOQUIRURGICA?',
#  'PIE CAVO SEVERO BILATERAL, SINTOMAICO REMAPATICO',
#  'RNT  40 SEM, GEG, POLIDACTILIA PRE AXIAL',
#  'COLECISTOLITIASIS OBS. NEO VESICILAR COLICOS A REPETICION.',
#  'MULTIPARA2 ( G4P2A2) ABORTOS REPETITIVOS PAP ATIPICO SIN TRATAMIENTO',
#  'DOLOR OSEO BENIGNO RECURRENTE V/S ¿FASCITIS PLANTAR? OBESIDAD COSNTIPACION FUNCIONAL',
#  'TALLA BAJA < 5P ( 112CM). ESCOLAR EUTROFICO',
#  'ISQUEMIA SUBENOSCARDIACA? HTA+DM IRC ET 3',
#  'OBS.LESION MENISCOS RODILLA DERECHA.',
#  'I489 FIBRILACIÓN Y ALETEO AURICULAR, NO ESPECIFICADO FA   DE INICIO  NO  PRECISADO',
#  'restos radiculares 2.6 , 4.4, se solicita realizar exodoncias',
#  'Pieza 7 tratada endodonticamente, extensa destrucciNn coronaria',
#  'DIENTE 1.8 Y 2.8 INCLUIDOS, DIENTE 3.8 Y 4.8 SEMIERUPCIONADOS, CON RAICES FUSIONADAS',
#  'DESDENTADO COMPLETO. PROTESIS EN MAL ESTADO.',
#  'PIEZA 17 4.8 SEMIERUPCIONADA',
#  'IMPLANTE PIEZA 4,5, 12  AUSENTES.',
#  'CHALAZION  AG',
#  'L81 OTROS TRASTORNOS DE LA PIGMENTACIÓN',
#  'PULPITIS PIEZA 4.2',
#  'DISCREPANCIA DENTOMAXILAR EN DENTICION MIXTA SEGUNDA FASE',
#  'INFANTO ANTIGUO DEL MIOCARDIO',
#  'OSTEITIS APICAL PIEZA DENTARIA 4, OBTURACION PENETRANTE.',
#  'LLAU LLAU',
#  'M3 USUARIA DIU + - 15 AÑOS SE SOLICITA EXTIRPACION VASTAGOS NEGATIVOS',
#  'P 9 DESTRUCCION CORONARIA EXTERNAS',
#  'FA PAROXISTICA S/ TACO IC CON FE-16 HTA TABAQUISMO',
#  'DM2 IR ESQUEMA INTENSIFICADO DESCOMPENSADO mayor Nefropatía establecida (clínica)',
#  '1- APIÑAMIENTO DENTARIO PIEZA ll',
#  'BRUXISMO - TRAUMA OCLUSAL - FACETAS DE DESGASTE',
#  'OBT Profunda pza 4.',
#  'posibilidad de realizar protesis inmediata',
#  'primigesta emb 34+4 semanas x fur obs macrosomia fetal',
#  '- ALTERACIONES EN LA ERUPCIÓN DENTARIA/  - Fundamento Clínico APS: Relacion molar:  clase 1 molar  Relacion incisiva: Overjet  normal y overbite  aumentado  Mm faltantes para ordenar dientes superiores: medio , apiñamiento dentario y rotación de la pieza 2.1  Mm faltantes para ordenar dientes inferiores:  apiñamiento dentario medio Mordida cruzada posterior ausente  Dolor ATM: No Asimetria facial: leve   Alteraciones en la erupcion dentaria',
#  'diente 32caries vestibular',
#  'Tendinosis Manguito Rotador Hombros Bilateral, Mayor A Derecha',
#  'TERCER MOLAR RETENIDO PIEZA 32',
#  '-PIEZA 2.7 CARIE PENETRANTE -SE DERIVA PARA EVALUACION Y TRATAMIENTO',
#  'FRENILLO LABIAL SUPERIOR CORTO, A NIVEL ESPACIO INTERINCISIVO REQUIERE EVALUACION POR ESPECIALIDAD',
#  'A638 - Otras enfermedades de transmision predominantemente sexual, especificadas',
#  'orbitopqatia  de graves',
#  'Prepucio Dolor',
#  'mordida abierta posteriorprognatismo mandibular',
#  'DESDENTADO PARCIAL- DIAGNOSTICO PRINCIPAL  DESDENTADO TOTAL',
#  'pd. 1.4 presento caries profunda, pulpitis irreversible. pd fue trepanaday quedo con pmnca y eugenato. solicito realizar endodoncia.',
#  'PACIENTE DENTICION DEFINITIVA APIÑAMIENTO DENTARIO PIEZA 2.3 SENI INCLUIDA POR FALTA DE ESPACIO.',
#  't.d.a antiguo año 2009',
#  'DESEA REPONER LENTES ANTERIORES EXTRAVIADOS',
#  'Hernias inguinales bilaterales',
#  'TRAST. DE DISCOS INTERV. LUMBARES',
#  'NECROSIS DE LA PULPA, PIEZA 1,1 TREPANADA.',
#  'EMB. 35 SEM. FUR 150815  PTGO ALTERADO',
#  'SD. JAQUECOSO REFRACTARIO',
#  'TU BENIGNO MUCOSA BUCAL',
#  '- AMENORREA PRIMARIAamenorrea primaria\n\n\n paciente 19 años sin menstruacion a la fecha , nunca, sin iniicio de relaciones sexuales,',
#  'NODULO  TIROIDEO  SOLITARIO',
#  'DM T 2 IRREGULAR??? CASO SOCIAL?',
#  'EXODONCIA P. 4.6 P. 4.6 CARIES PROFUNDAS. HIPER  CEMENTOSIS.',
#  'CISTOCELE GRADO II + IOE',
#  'CARIES PENETRANTES\xa0',
#  'PROBLEMAS RELACIONADOS CON LA LIMITACION DE LAS ACTIVIDADES DEBIDO A DISCAPACIDAD ,RESTO RADICULAR',
#  'DENTACION TEMPRANA COMPLETA',
#  '- CARIES DENTINARIA PENETRANTE/  - Fundamento Clínico APS: 2.5 caries epentrante, trepanada, 2 conductos. requiere tratamiento de conducto. Caries del cemento',
#  'Bloqueo bi fasciular con extrasistolias frecuentes',
#  '- Disfagia. - Dismiticulosis',
#  'se solicita evaluar',
#  'OBS. DE PTERIGION OJO IZQUIERDO.,',
#  'TRAPANACION PZA 13',
#  'M1-PTV (22 AÑOS) MENOP.PROJ SECUNDARIA ALTO X CACU',
#  'apiñamiento dentario\xa0',
#  'ESQUINCE MAXILO FACIAL',
#  'pza 2.2 trepanada, clinico + 3 rx.',
#  'arttrodesis subtala izq.',
#  'DIENTE 32 SEMIERUPCIONADO CON RAICES CURVAS HACIA DISTAL, DIENTE 1 Y 16 SEMIERUPCIONADOS CON RAICES CURVAS HACIA DISTAL.',
#  'FRACTURA 2DO FALANGE DEDO ANULAR IZQUIERDO.-',
#  '- ANOMALÍAS DE LA POSICIÓN DEL DIENTE/  - Fundamento Clínico APS: PRESENTA APIÑAMIEMTO ANTERIOR SUPERIOR E INFERIOR PIEZAS 3.3 Y 4.3 CON GIRVERSION CON LEVE MORDIDA VIS A VIS Anomalias de la posicion del diente',
#  '- EPISODIO DEPRESIVO MODERADO/ - HIPERTENSIÓN ESENCIAL (PRIMARIA)/ - MIGRAÑA SIN AURA MIGRAÑA COMÚN/  - Fundamento Clínico APS: PACIENTE CON ANTECEDENTE DE MIGRAÑA DE LARGA DATA (MAS DE 18 AÑOS), ULTIMO TAC HACE 4 AÑOS: NORMAL. EX NEUROLOGICO SIN ALTERACIONES. PACIENTE USUARIA DE MIGRANOL EN FORMA CRONICA (1 A 3 COMP X DIA). PERSISTE CON CEFALEA. SE DERIVA A ESPECIALISTA PARA MANEJO DE MIGRAÑA.  Migraña sin aura migraña comun',
#  'TERCEROS MOLARES SEMIINCLUIDOS CON CARIES',
#  'OBS.SINDROME POLIGLANDULA TIPO II SD. METABOLICO.',
#  'RETRACCION FLEXORA DEL 2º ORTEJO DERECHO',
#  '- MALOCLUSIÓN DE TIPO NO ESPECIFICADO/  - Fundamento Clínico APS: Paciente clase molar 2 con protrusion del grupo dos.  Over bite elevemente disminuido y  over jet aumentado.   Maloclusion de tipo no especificado',
#  'POLIPO ENDOMETRIAL . HIPERMENORREA. PRESENTA MENSTRUACIONES ABUNDANTES DE 8 A 10 DIAS DE DURACION',
#  'P8 PERIODONTITIS APICAL SINTOMATICA EN PEEZA CON TERAPIA PREVIAMENTE INICIADA.',
#  'TRASTORNOS DE LOS TENDONES Y DE LA SINOVIA EN ENFERMEDADES CLASIFICADAS EN OTRA PARTE,(TRASTORNOS DE LOS TENDONES Y DE LA SINOVIA)',
#  '- OTROS QUISTES FOLICULARES DE LA PIEL Y DEL TEJIDO SUBCUTÁNEO/  - Fundamento Clínico APS: Paciente sin antecedentes morbidos, presenta lesión en mejilla derecha de aproximadamente 1 año de evolución, con crecimiento en los ultimos meses. Lesión quistica de aproximadamente 1 cm de diametro mayor, sin adherencia a planos profundos. Eco de partes blandas muestra aspecto de quiste de inclusión dermica. Se deriva para resolución quirurgica ya que no se cuenta con programa de cirugias menores en este servicio. Otros quistes foliculares de la piel y del tejido subcutaneo',
#  'HERNIA INGUINOESCROTAL IZQUIERDA COMPLICADA EPOC SEVERO ESTABLE.',
#  'B349 INFECCIÓN VIRAL, NO ESPECIFICADA PACIENTE TRASPLNTADA INMUNOCOMPROMETIDA EN ESTE CONTEXTO  REFIRE INFECCION DE PIEZA DENTAL LUEGO DE EXTRACCION\nSE SOLICITA EVLAUCION ODONTOÓGICA A LA BREVEDAD',
#  'OBSERVACION LUMBOCIATICA HNP?',
#  'CEFALEA POST TECT CERRADO',
#  'VICIO DE REFRACCION  HTA+ DM +DLP',
#  'FRACTURA DE CABEZA DE HUMERO DERECHO.-',
#  'favor evaluar y realizar tratamiento si corresponde Anomalias dentofaciales (incluso la maloclusion)',
#  '- FRACTURA DE OTRO DEDO DE LA MANO/ - CONSOLIDACIÓN DEFECTUOSA DE FRACTURA/  - Fundamento Clínico APS: Paciente sufre trauma primer ortejo hace 1 mes mano derecha  con objeto contundenteno se evaluo con radiografia inicial, fue tratada con inmovilizacion',
#  'PULPITIS / pulpitis',
#  '- pieza 3.6 trepanada-necrosis pulpar',
#  'PG. GEST. 27 +4 SEM. DIABETES GESTACIONAL',
#  '- ANOMALÍAS DENTOFACIALES (INCLUSO LA MALOCLUSIÓN)/  - Fundamento Clínico APS: Paciente de 7 años, apto para la consulta odontologica quien esta con alta integral GES a los 6 años, se ordeno rx panoramica de control, se observa denticion mixta con presencia de premolares definitivos, clinicamente se oberva anomalias dentomaxilares con las siguientes caracteristicas: una  relacion esqueletal clase III, relacion molar mesioclusion, relacion canina mesioclusion, relacion incisva mordia invertida, con apiñamientos anteriores superires y rotacion del 1.1 y 2.1, se realiza intercosnulta a ortodoncai a hospital de Copiapó para manejo del caso por especialista ortodoncista. Anomalias dentofaciales (incluso la maloclusion)',
#  'TENOSINOVITIS ESTENOSANTE 3ER. DEDO MANO IZQUIERDA.',
#  'PACIENTE  HTA  DESDENTADA  PARCIAL  MAXILAR  CLASE   III   DE  KENNEDY   MODIFICACION  1',
#  'Evaluacion De Tratamiento',
#  'OSTEOPENIA LEVE VERTEBRA DE TRANSICION LUMBOSACRA DISCOPASTIA',
#  'PACIENTE DESDENTADO PARCIAL INF Y SUP- REALIZAR PROTESIS PARCIAL INFERIOR',
#  ...]

# %% [markdown]
# Esto podría tardar un poco, por que se recomienda escribir el código de las siguientes secciones mientras se cargan los archivos. Una vez terminado eso. Corra la celda de pandas para asegurarse que el archivo fue cargado.

# %% [markdown]
# El dataset esta compuesto por dos filas, que son:
#
# - La etiqueta que indica la categoría del diagnostico.
# - El contenido del diagnostico.

# %% [markdown]
# Para cargar el dataset a pytorch usaremos una función similar a la del tutorial 5 para cargar crear el generador y construir el objeto del dataset en `PyTorch`.

# %%
def load_dataset(dataset, mode):
  return tuple(zip(dataset[mode]['label'], dataset[mode]['text']))

# %% [markdown]
# Luego, ejecutamos la función tanto los datasets de `train` y `test`:

# %%
train_dataset = load_dataset(spanish_diagnostics, 'train')
test_dataset = load_dataset(spanish_diagnostics, 'test')

# %% [markdown]
# Ahora el siguiente gran paso es crear Vocabulario usando `torchtext`, una sub librería de `PyTorch` que implementa diferentes clases y modulos para trabajar con métodos de Deep Learning en NLP.

# %% [markdown]
# ### Crear vocabulario
#
# Una vez que hemos cargado el dataset, es necesario crear nuestro vocabulario a partir de los tokens que componen nuestro dataset. Para esto, se deben seguir los siguientes pasos:
#
# - Es necesario tokenizar el dataset.
# - A partir del el dataset tokenizado, se crea el vocabulario.

# %%
import torch
from torchtext.data import get_tokenizer
from torchtext.vocab import build_vocab_from_iterator

# %%
tokenizer = get_tokenizer("basic_english")

def build_vocabulary(datasets):
    for dataset in datasets:
        for _, text in dataset:
            yield tokenizer(text)

vocab = build_vocab_from_iterator(build_vocabulary([train_dataset, test_dataset]), min_freq=1, specials=["<UNK>"])

vocab.set_default_index(vocab["<UNK>"])

# %% [markdown]
# # Cargar el `DataLoader`

# %%
from torch.utils.data import DataLoader
from torchtext.data.functional import to_map_style_dataset

# %%
train_dataset, test_dataset  = to_map_style_dataset(train_dataset), to_map_style_dataset(test_dataset)


max_words = 25

# %% [markdown]
# Antes de cargar los dataset es necesario, definir una función que sea capaz de procesar el `batch` que se va extrayendo al entrenar este modelo. Para entender más detalles de esto, se sugiere revisar este [link](https://chadrick-kwag.medium.com/how-does-pytorch-dataloader-gather-data-from-into-batches-pytorch-f02b96bc859d).

# %%
def vectorize_batch(batch):

    Y, X = list(zip(*batch))
    X = [vocab(tokenizer(text)) for text in X]
    X = [tokens+([0]* (max_words-len(tokens))) if len(tokens)<max_words else tokens[:max_words] for tokens in X]

    return torch.tensor(X, dtype=torch.int32), torch.tensor(Y)

# %% [markdown]
# Con esto ya podemos crear el objeto del `DataLoader` para cargar el dataset en `PyTorch`.

# %%
train_loader = DataLoader(train_dataset, batch_size=1024, collate_fn=vectorize_batch, shuffle=True)
test_loader  = DataLoader(test_dataset , batch_size=1024, collate_fn=vectorize_batch)

# %% [markdown]
# El siguiente paso es definir el modelo de nuestra red, que se utilizará para entrenar el clasificador.

# %% [markdown]
# ### Definir el modelo

# %%
from torch import nn
from torch.nn import functional as F

# %% [markdown]
# Un detalle más importante, es siempre definir los hyperparametros de un modelo, se sugiere utilizar los mismos del tutorial.

# %%
embed_len = 50
hidden_dim = 50
n_layers=1

# %% [markdown]
# Finalmente, usted debe agregar el código para definir el clasificador. Esto consta de dos partes:
#
# - Primero, en el constructor `__init__` debe definir que capas son necesarias dentro del clasificador.
# - Segundo, debe implementar el método `forward`, donde se ejecutan todos los pasos que usted estime conveniente en la red neuronales.

# %%
class RNNClassifier(nn.Module):
    def __init__(self):
        pass
        # Implementar.

    def forward(self, X_batch):
        pass
        # Implementar.

# %% [markdown]
# ### Funciones de entrenamiento y Evaluación
#
# Para evaluar el modelo usaremos las funciones del tutorial, no profundizaremos mucho en ellas por falta de tiempo, pero básicamente, la función `CalcValLossAndAccuracy` se encarga calcular la función de pérdida y el acuraccy en cada llamada al modelo, y la función `TrainModel`, entrena todo el modelo.

# %%
from tqdm import tqdm
from sklearn.metrics import accuracy_score
import gc

# %%
def CalcValLossAndAccuracy(model, loss_fn, val_loader):
    with torch.no_grad():
        Y_shuffled, Y_preds, losses = [],[],[]
        for X, Y in val_loader:
            preds = model(X)
            loss = loss_fn(preds, Y)
            losses.append(loss.item())

            Y_shuffled.append(Y)
            Y_preds.append(preds.argmax(dim=-1))

        Y_shuffled = torch.cat(Y_shuffled)
        Y_preds = torch.cat(Y_preds)

        print("Valid Loss : {:.3f}".format(torch.tensor(losses).mean()))
        print("Valid Acc  : {:.3f}".format(accuracy_score(Y_shuffled.detach().numpy(), Y_preds.detach().numpy())))


def TrainModel(model, loss_fn, optimizer, train_loader, val_loader, epochs=10):
    for i in range(1, epochs+1):
        losses = []
        for X, Y in tqdm(train_loader):
            Y_preds = model(X)

            loss = loss_fn(Y_preds, Y)
            losses.append(loss.item())

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

        print("Train Loss : {:.3f}".format(torch.tensor(losses).mean()))
        CalcValLossAndAccuracy(model, loss_fn, val_loader)

# %% [markdown]
# ### Entrenamiento del modelo.
#
# Ahora relizamos el entrenamiento del modelo, esto podría tardar un poco, pero recuerde estar ejecutando su modelo en la GPU del google colab y no la CPU, ya que tardará muchisímo más.

# %%
from torch.optim import Adam

# %%
epochs = 10
learning_rate = 1e-3

loss_fn = nn.CrossEntropyLoss()
rnn_classifier = RNNClassifier()
optimizer = Adam(rnn_classifier.parameters(), lr=learning_rate)

TrainModel(rnn_classifier, loss_fn, optimizer, train_loader, test_loader, epochs)
# Out:
# 100%|██████████| 69/69 [00:07<00:00,  8.63it/s]
# Train Loss : 0.692
# Valid Loss : 0.690
# Valid Acc  : 0.524
# 100%|██████████| 69/69 [00:06<00:00, 10.09it/s]
# Train Loss : 0.644
# Valid Loss : 0.528
# Valid Acc  : 0.768
# 100%|██████████| 69/69 [00:05<00:00, 12.11it/s]
# Train Loss : 0.414
# Valid Loss : 0.404
# Valid Acc  : 0.837
# 100%|██████████| 69/69 [00:07<00:00,  9.52it/s]
# Train Loss : 0.306
# Valid Loss : 0.281
# Valid Acc  : 0.894
# 100%|██████████| 69/69 [00:06<00:00, 10.87it/s]
# Train Loss : 0.250
# Valid Loss : 0.251
# Valid Acc  : 0.909
# 100%|██████████| 69/69 [00:06<00:00, 10.95it/s]
# Train Loss : 0.226
# Valid Loss : 0.235
# Valid Acc  : 0.917
# 100%|██████████| 69/69 [00:06<00:00, 10.40it/s]
# Train Loss : 0.201
# Valid Loss : 0.219
# Valid Acc  : 0.922
# 100%|██████████| 69/69 [00:05<00:00, 12.05it/s]
# Train Loss : 0.189
# Valid Loss : 0.214
# Valid Acc  : 0.925
# 100%|██████████| 69/69 [00:06<00:00,  9.88it/s]
# Train Loss : 0.175
# Valid Loss : 0.208
# Valid Acc  : 0.933
# 100%|██████████| 69/69 [00:05<00:00, 12.01it/s]
# Train Loss : 0.164
# Valid Loss : 0.205
# Valid Acc  : 0.929

# %% [markdown]
# ### Realizar prediciones de la Red entrenada.
#
# Para evaluar el modelo usaremos las mismas funciones del tutorial, que son:

# %%
def MakePredictions(model, loader):
    Y_shuffled, Y_preds = [], []
    for X, Y in loader:
        preds = model(X)
        Y_preds.append(preds)
        Y_shuffled.append(Y)
    gc.collect()
    Y_preds, Y_shuffled = torch.cat(Y_preds), torch.cat(Y_shuffled)

    return Y_shuffled.detach().numpy(), F.softmax(Y_preds, dim=-1).argmax(dim=-1).detach().numpy()

Y_actual, Y_preds = MakePredictions(rnn_classifier, test_loader)

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

Y_actual, Y_preds = MakePredictions(rnn_classifier, test_loader)

print("Test Accuracy : {}".format(accuracy_score(Y_actual, Y_preds)))
print("\nClassification Report : ")
print(classification_report(Y_actual, Y_preds))
print("\nConfusion Matrix : ")
print(confusion_matrix(Y_actual, Y_preds))
# Out:
# Test Accuracy : 0.9291
#
# Classification Report :
#               precision    recall  f1-score   support
#
#            0       0.94      0.91      0.93     15034
#            1       0.92      0.94      0.93     14966
#
#     accuracy                           0.93     30000
#    macro avg       0.93      0.93      0.93     30000
# weighted avg       0.93      0.93      0.93     30000
#
#
# Confusion Matrix :
# [[13739  1295]
#  [  832 14134]]

# %% [markdown]
# Ahora proponga otra arquictura en RNN, y vuelta a re-entrenar el modelo. ¿Existe una diferencia en su performance? Sí es así, ¿Porqué cree que sucede esto?

# %%
class RNNClassifier(nn.Module):
    def __init__(self):
      pass
    def forward(self, X_batch):
      pass
